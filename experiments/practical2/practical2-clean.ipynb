# %% [markdown]
# ## Practical 2: Text Classification with Word Embedding
# <p>Oxford CS - Deep NLP 2017<br>
# https://www.cs.ox.ac.uk/teaching/courses/2016-2017/dl/</p>
# <p>[Yannis Assael, Brendan Shillingford, Chris Dyer]</p>

# %%
import numpy as np
import time
import os
from random import shuffle
import re

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e20bac8c-0c83-4df1-82f5-d1275d0b4621">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Load TED dataset

# %%
import urllib.request
import zipfile
import lxml.etree

# %%
# Download the dataset if it's not already there: this may take a minute as it is 75MB
if not os.path.isfile('ted_en-20160408.zip'):
    urllib.request.urlretrieve("https://wit3.fbk.eu/get.php?path=XML_releases/xml/ted_en-20160408.zip&filename=ted_en-20160408.zip", filename="ted_en-20160408.zip")

# %%
with zipfile.ZipFile('ted_en-20160408.zip', 'r') as z:
    doc = lxml.etree.parse(z.open('ted_en-20160408.xml', 'r'))

doc_list = doc.xpath('//content/text()')
label_list = doc.xpath('//keywords/text()')
# input_text = '\n'.join(doc_list)
del doc

# %%
def get_label(keywords, label_dict):
    label_string = keywords.lower()
    if ("technology" in label_string) and ("entertainment" in label_string) and ("design" in label_string):
        return label_dict['TED']
    elif ("entertainment" in label_string) and ("design" in label_string):
        return label_dict['oED']
    elif ("technology" in label_string) and ("design" in label_string):
        return label_dict['ToD']
    elif ("technology" in label_string) and ("entertainment" in label_string):
        return label_dict['TEo']
    elif ("design" in label_string):
        return label_dict['ooD']
    elif ("entertainment" in label_string):
        return label_dict['oEo']
    elif ("technology" in label_string):
        return label_dict['Too']
    else:
        return label_dict['ooo']

# %%
labels = ['ooo', 'Too', 'oEo', 'ooD', 'TEo', 'ToD', 'oED', 'TED']
label_dict = {labels[i]: i for i in range(8)}

label_list_temp = [get_label(keywords, label_dict) for keywords in label_list]   
labelled_doc = list(zip(doc_list, label_list_temp))
# Out:
# talks, business, creativity, curiosity, goal-setting, innovation, motivation, potential, success, work
# talks, Planets, TEDx, bacteria, biology, engineering, environment, evolution, exploration, future, innovation, intelligence, microbiology, nature, potential, science
# talks, Debate, Guns, activism, big problems, children, choice, community, future, goal-setting, government, law, leadership, marketing, parenting, policy, social change, violence
# talks, Brazil, Slavery, art, beauty, community, creativity, culture, design, global issues, humanity, identity, photography, race, social change, society, visualizations
# talks, NASA, communication, computers, creativity, design, engineering, exploration, future, innovation, interface design, invention, microsoft, potential, prediction, product design, technology, visualizations
# talks, Africa, Internet, community, democracy, development, future, government, identity, leadership, politics, potential
# talks, ancient world, animals, biology, biosphere, curiosity, environment, evolution, history, life, nature, paleontology, science
# talks, TEDx, business, culture, economics, personal growth, success, work
# talks, Criminal Justice, big problems, choice, compassion, decision-making, education, government, inequality, law, leadership, policy, race, social change, society
# talks, Senses, augmented reality, brain, computers, creativity, cyborg, demo, design, engineering, entrepreneur, innovation, interface design, invention, neuroscience, potential, prediction, product design, technology, visualizations

# %%
from random import sample

def divide_dataset(labelled_doc, num_train, num_valid, num_test=None, shuffle=False):
    if num_test == None:
        num_test = len(labelled_doc) - num_train - num_valid
        
    if shuffle:
        temp = sample(labelled_doc, len(labelled_doc))
    else:
        temp = labelled_doc
    return temp[:num_train], temp[num_train:-num_test], temp[-num_test:]

# %%
train_doc_temp, valid_doc_temp, test_doc_temp = divide_dataset(labelled_doc, 1585, 250, 250, shuffle=True)

print(len(train_doc_temp), len(valid_doc_temp), len(test_doc_temp))
# Out:
# 1585
# 250
# 250

# %% [markdown]
# ## Build vocabulary using training set

# %%
from collections import Counter 

def tokenize_and_lowercase(text):
    text_noparens = re.sub(r'\([^)]*\)', '', text)
    sentences_strings = []
    for line in text_noparens.split('\n'):
        m = re.match(r'^(?:(?P<precolon>[^:]{,20}):)?(?P<postcolon>.*)$', line)
        sentences_strings.extend(sent for sent in m.groupdict()['postcolon'].split('.') if sent)
        
    sentences= []
    for sent_str in sentences_strings:
        tokens = re.sub(r"[^a-z0-9]+", " ", sent_str.lower()).split()
        sentences.append(tokens)
    return sentences

def get_most_common_words_list(sentences, num_words):
    counts_ted_top1000 = []
    c = Counter([word for sent in sentences for word in sent])
    list_most_common = c.most_common(num_words)
    words_most_common = [item[0] for item in list_most_common]
    #for word, count in list_most_common:
    #    counts_ted_top1000.append(count)
    return words_most_common
    
def replace_unknown_token(sent_list, words_most_common, unknown_token="UNK"):
    filtered_list = [word if word in words_most_common else unknown_token for word in sent_list]  # so fast !!!
    return filtered_list

def tokenize_and_lowercase_most_common(text, words_most_common):
    text_noparens = re.sub(r'\([^)]*\)', '', text)
    sentences_strings = []
    for line in text_noparens.split('\n'):
        m = re.match(r'^(?:(?P<precolon>[^:]{,20}):)?(?P<postcolon>.*)$', line)
        sentences_strings.extend(sent for sent in m.groupdict()['postcolon'].split('.') if sent)
        
    sentences= []
    for sent_str in sentences_strings:
        tokens = replace_unknown_token(re.sub(r"[^a-z0-9]+", " ", sent_str.lower()).split(), words_most_common)
        if tokens != []:
            sentences.append(tokens)
    return sentences

def build_dataset(doc_temp, words_most_common):
    doc_new = [(tokenize_and_lowercase_most_common(doc[0], words_most_common), doc[1]) for doc in doc_temp]
    doc_final = [item for item in doc_new if item[0] != []]
    return doc_final

# %%
input_text = '\n'.join([train_doc_temp[i][0] for i in range(len(train_doc_temp))])
sentences_ted = tokenize_and_lowercase(input_text)
# train_doc = [(tokenize_and_lowercase(doc_temp[0]), doc_temp[1]) for doc_temp in train_doc_temp]

# Get the list of 9999 most common words 
words_most_common = get_most_common_words_list(sentences_ted, 9999)

# Training set 
train_doc = [(tokenize_and_lowercase_most_common(doc_temp[0], words_most_common), doc_temp[1]) for doc_temp in train_doc_temp]

# %% [markdown]
# ### Rebuild the vocabulary

# %%
def rebuild_vocab(train_doc):
    """ filtered out unknow tokens, rebuild the dataset with the top vocabulary.
    """
    sentences = [sent for doc in train_doc for sent in doc[0]]
    return sentences

# %%
sentences = rebuild_vocab(train_doc)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Word2Vec Embedding

# %%
import os 
from gensim.models import Word2Vec

def build_word2vec_model(name, sentences=None, min_count=10, size=100):
    if not os.path.isfile(name):
        model = Word2Vec(sentences, min_count=min_count, size=size)
        model.save(name)
    else:
        model = Word2Vec.load(name)
    return model

# %%
model = build_word2vec_model('word2vec_model', , sentences=sentences, min_count=10, size=100)

# %% [markdown]
# ## Dataset

# %%
# Training set 
train_doc = build_dataset(train_doc_temp, words_most_common)

# Validation set 
valid_doc = build_dataset(valid_doc_temp, words_most_common)

# Test set 
test_doc = build_dataset(test_doc_temp, words_most_common)

# %%
np.savez('corpus_all_9999', train_doc=train_doc, valid_doc=valid_doc, test_doc=test_doc)

# %% [markdown]
# ## Bag of Means

# %%
def embed_text(model, text):
    """ embed the input text as a model vector 
    
    Arguments:
        model: Word2Vec model.
        text: input text
    
    Outputs:
        embedded vector 
    """
    vector_list = [model.wv[word] for sent in text for word in sent]
    return sum(vector_list) / len(vector_list)
    
def embed_corpus(model, corpus):
    return np.asarray([embed_text(model, doc[0]) for doc in corpus])

def encode_label(label, size):
    l = [0]*size
    l[label] = 1
    return l

def encode_class(corpus, size):
    return np.asarray([encode_label(doc[1], size) for doc in corpus])

def embedded_with_class(model, doc, size):
    doc_x = embed_corpus(model, doc)
    doc_y = encode_class(doc, size)
    return doc_x, doc_y

# %%
# train_doc_embedded = embed_corpus(model, train_doc)

train_doc_embed_with_class = embedded_with_class(model, train_doc, len(label_dict))
valid_doc_embed_with_class = embedded_with_class(model, valid_doc, len(label_dict))
test_doc_embed_with_class = embedded_with_class(model, test_doc, len(label_dict))

# %%
np.savez('embedded_corpus_all_9999', train_doc_embedded=train_doc_embed_with_class,
         valid_doc_embedded=valid_doc_embed_with_class, test_doc_embedded=test_doc_embed_with_class)

# %% [markdown]
# ## TensorFlow model

# %%
import tensorflow as tf

# %%
epoch = 2000
learning_rate = 0.0001
batch_size = 50
total_batch = int(train_doc_embedded.shape[0] / batch_size)
index = 0
# Out:
# 31

# %%
x = tf.placeholder(tf.float32, shape=[None, 100])
y = tf.placeholder(tf.int32, shape=[None, 8])

# %%
W = tf.Variable(tf.truncated_normal(shape=[100, 256]))
b = tf.Variable(tf.constant(0.0, shape=[256]))

V = tf.Variable(tf.truncated_normal(shape=[256, 8]))
c = tf.Variable(tf.constant(0.0, shape=[8]))

# %%
h = tf.tanh(tf.matmul(x, W) + b)
u = tf.matmul(h, V) + c

p = tf.nn.softmax(u)
pred = tf.argmax(p, 1)

# %%
loss = tf.reduce_mean(tf.reduce_sum(-tf.cast(y, tf.float32)*tf.log(tf.clip_by_value(p, 1e-10, 1.0)), 1))
# loss = tf.reduce_mean(tf.reduce_sum(-tf.cast(y, tf.float32)*tf.log(p), 1))

accuracy = tf.reduce_mean(tf.cast(tf.equal(pred, tf.argmax(y, 1)), tf.float32))

# %%
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)

# %%
saver = tf.train.Saver()

# %%
def next_batch(data, index, size):
    """ return next batch in format: index, x batch, y batch
    """
    if index + size <= data[0].shape[0]:
        return index+size, data[0][index:index+size], data[1][index:index+size]
    else:
        return index+size-data[0].shape[0], np.concatenate((data[0][index:],data[0][:index+size-data[0].shape[0]]), 0), \
    np.concatenate((data[1][index:],data[1][:index+size-data[1].shape[0]]), 0)

# %% [markdown]
# ### Validation

# %%
x_valid, y_valid = (valid_doc_embed_with_class[0], valid_doc_embed_with_class[1])

# %%
sess = tf.InteractiveSession()

# %%
init = tf.global_variables_initializer()
sess.run(init)

# %%
for i in range(epoch):
    xloss = 0
    
    for j in range(total_batch):
        # need to incoporate y in the batches and expand to 8 classes 
        index, x_, y_ = next_batch(train_doc_embed_with_class, index, batch_size)
        _, xloss = sess.run([optimizer, loss], feed_dict={x: x_, y: y_})
        
        if j % 10 == 0:
            print("epoch %d, run %d, loss %g" % (i, j, xloss))
            
    if i % 100 == 0:
        acc = sess.run(accuracy, feed_dict={x:valid_doc_embed_with_class[0], y:valid_doc_embed_with_class[1]})
        print("Validation acc: %g" % (acc * 100), end="")
        print("%")
        
save_path = saver.save(sess, "/tmp/validation_model"+str(time.time())+".ckpt")
print("Model saved in file: %s" % save_path)
# Out:
# epoch 0, run 0, loss 18.2937
# epoch 0, run 10, loss 8.32358
# epoch 0, run 20, loss 6.38116
# epoch 0, run 30, loss 7.52312
# epoch 1, run 0, loss 5.39021
# epoch 1, run 10, loss 4.09569
# epoch 1, run 20, loss 3.92336
# epoch 1, run 30, loss 5.10267
# epoch 2, run 0, loss 5.87365
# epoch 2, run 10, loss 1.41565
# epoch 2, run 20, loss 3.9831
# epoch 2, run 30, loss 4.16819
# epoch 3, run 0, loss 5.06596
# epoch 3, run 10, loss 1.5319
# epoch 3, run 20, loss 2.74353
# epoch 3, run 30, loss 2.56959
# epoch 4, run 0, loss 3.12929
# epoch 4, run 10, loss 1.81007
# epoch 4, run 20, loss 2.54993
# epoch 4, run 30, loss 2.5161
# epoch 5, run 0, loss 2.72305
# epoch 5, run 10, loss 2.00362
# epoch 5, run 20, loss 2.17282
# epoch 5, run 30, loss 2.11775
# epoch 6, run 0, loss 2.05125
# epoch 6, run 10, loss 1.12926
# epoch 6, run 20, loss 1.57404
# epoch 6, run 30, loss 2.68889
# epoch 7, run 0, loss 1.82154
# epoch 7, run 10, loss 1.21378
# epoch 7, run 20, loss 1.54869
# epoch 7, run 30, loss 2.48492
# epoch 8, run 0, loss 2.01407
# epoch 8, run 10, loss 1.0959
# epoch 8, run 20, loss 1.35992
# epoch 8, run 30, loss 2.16041
# epoch 9, run 0, loss 2.35292
# epoch 9, run 10, loss 1.01449
# epoch 9, run 20, loss 1.30452
# epoch 9, run 30, loss 2.27657
# epoch 10, run 0, loss 2.07742
# epoch 10, run 10, loss 1.04622
# epoch 10, run 20, loss 1.01312
# epoch 10, run 30, loss 2.0384
# epoch 11, run 0, loss 1.85266
# epoch 11, run 10, loss 1.24888
# epoch 11, run 20, loss 1.50245
# epoch 11, run 30, loss 1.93101
# epoch 12, run 0, loss 2.17859
# epoch 12, run 10, loss 1.03028
# epoch 12, run 20, loss 1.20928
# epoch 12, run 30, loss 2.3415
# epoch 13, run 0, loss 1.6095
# epoch 13, run 10, loss 0.870363
# epoch 13, run 20, loss 1.21301
# epoch 13, run 30, loss 1.77399
# epoch 14, run 0, loss 2.01263
# epoch 14, run 10, loss 1.26134
# epoch 14, run 20, loss 1.43626
# epoch 14, run 30, loss 2.0625
# epoch 15, run 0, loss 2.35117
# epoch 15, run 10, loss 1.38772
# epoch 15, run 20, loss 1.58483
# epoch 15, run 30, loss 2.14491
# epoch 16, run 0, loss 1.92947
# epoch 16, run 10, loss 1.26901
# epoch 16, run 20, loss 1.75397
# epoch 16, run 30, loss 1.69544
# epoch 17, run 0, loss 2.0851
# epoch 17, run 10, loss 1.12518
# epoch 17, run 20, loss 1.56094
# epoch 17, run 30, loss 0.977293
# epoch 18, run 0, loss 1.76498
# epoch 18, run 10, loss 0.837866
# epoch 18, run 20, loss 1.08724
# epoch 18, run 30, loss 0.756012
# epoch 19, run 0, loss 1.43387
# epoch 19, run 10, loss 1.50747
# epoch 19, run 20, loss 0.876082
# epoch 19, run 30, loss 1.14838
# epoch 20, run 0, loss 0.730237
# epoch 20, run 10, loss 1.77452
# epoch 20, run 20, loss 0.77121
# epoch 20, run 30, loss 1.39547
# epoch 21, run 0, loss 0.812044
# epoch 21, run 10, loss 1.36034
# epoch 21, run 20, loss 0.473988
# epoch 21, run 30, loss 1.32269
# epoch 22, run 0, loss 1.07204
# epoch 22, run 10, loss 1.2927
# epoch 22, run 20, loss 0.864372
# epoch 22, run 30, loss 1.30562
# epoch 23, run 0, loss 1.27571
# epoch 23, run 10, loss 1.21165
# epoch 23, run 20, loss 0.87348
# epoch 23, run 30, loss 1.04468
# epoch 24, run 0, loss 1.30471
# epoch 24, run 10, loss 1.09433
# epoch 24, run 20, loss 0.795379
# epoch 24, run 30, loss 0.968064
# epoch 25, run 0, loss 1.23411
# epoch 25, run 10, loss 1.16623
# epoch 25, run 20, loss 0.775623
# epoch 25, run 30, loss 1.00924
# epoch 26, run 0, loss 1.02998
# epoch 26, run 10, loss 1.48905
# epoch 26, run 20, loss 0.59798
# epoch 26, run 30, loss 1.14845
# epoch 27, run 0, loss 0.943548
# epoch 27, run 10, loss 1.64535
# epoch 27, run 20, loss 0.824248
# epoch 27, run 30, loss 1.1001
# epoch 28, run 0, loss 1.00847
# epoch 28, run 10, loss 1.50484
# epoch 28, run 20, loss 1.01064
# epoch 28, run 30, loss 1.07568
# epoch 29, run 0, loss 1.03538
# epoch 29, run 10, loss 1.57066
# epoch 29, run 20, loss 0.733896
# epoch 29, run 30, loss 1.12181
# epoch 30, run 0, loss 0.779689
# epoch 30, run 10, loss 1.46379
# epoch 30, run 20, loss 0.688469
# epoch 30, run 30, loss 0.880135
# epoch 31, run 0, loss 1.19599
# epoch 31, run 10, loss 1.34681
# epoch 31, run 20, loss 0.715137
# epoch 31, run 30, loss 0.952319
# epoch 32, run 0, loss 0.932334
# epoch 32, run 10, loss 1.60198
# epoch 32, run 20, loss 0.927447
# epoch 32, run 30, loss 1.18225
# epoch 33, run 0, loss 0.808598
# epoch 33, run 10, loss 1.20005
# epoch 33, run 20, loss 1.08871
# epoch 33, run 30, loss 1.48811
# epoch 34, run 0, loss 0.944336
# epoch 34, run 10, loss 1.42079
# epoch 34, run 20, loss 1.07564
# epoch 34, run 30, loss 1.16715
# epoch 35, run 0, loss 1.26244
# epoch 35, run 10, loss 1.55225
# epoch 35, run 20, loss 0.756383
# epoch 35, run 30, loss 0.792552
# epoch 36, run 0, loss 1.48974
# epoch 36, run 10, loss 1.20201
# epoch 36, run 20, loss 1.05542
# epoch 36, run 30, loss 0.71451
# epoch 37, run 0, loss 1.09333
# epoch 37, run 10, loss 0.759772
# epoch 37, run 20, loss 1.59245
# epoch 37, run 30, loss 0.679113
# epoch 38, run 0, loss 0.820635
# epoch 38, run 10, loss 0.650643
# epoch 38, run 20, loss 1.1778
# epoch 38, run 30, loss 0.429998
# epoch 39, run 0, loss 0.759791
# epoch 39, run 10, loss 0.844454
# epoch 39, run 20, loss 1.16401
# epoch 39, run 30, loss 0.666692
# epoch 40, run 0, loss 0.700341
# epoch 40, run 10, loss 1.10256
# epoch 40, run 20, loss 1.06015
# epoch 40, run 30, loss 0.872662
# epoch 41, run 0, loss 0.339414
# epoch 41, run 10, loss 1.11808
# epoch 41, run 20, loss 1.05892
# epoch 41, run 30, loss 0.76988
# epoch 42, run 0, loss 0.668685
# epoch 42, run 10, loss 1.05191
# epoch 42, run 20, loss 1.11404
# epoch 42, run 30, loss 0.693769
# epoch 43, run 0, loss 0.669742
# epoch 43, run 10, loss 0.855806
# epoch 43, run 20, loss 1.37087
# epoch 43, run 30, loss 0.486656
# epoch 44, run 0, loss 0.606902
# epoch 44, run 10, loss 0.884741
# epoch 44, run 20, loss 1.35687
# epoch 44, run 30, loss 0.835149
# epoch 45, run 0, loss 0.64103
# epoch 45, run 10, loss 0.79345
# epoch 45, run 20, loss 1.17313
# epoch 45, run 30, loss 0.860363
# epoch 46, run 0, loss 0.53218
# epoch 46, run 10, loss 0.937594
# epoch 46, run 20, loss 1.19779
# epoch 46, run 30, loss 0.752378
# epoch 47, run 0, loss 0.746045
# epoch 47, run 10, loss 0.914089
# epoch 47, run 20, loss 1.15476
# epoch 47, run 30, loss 0.593614
# epoch 48, run 0, loss 0.809644
# epoch 48, run 10, loss 0.909766
# epoch 48, run 20, loss 1.1106
# epoch 48, run 30, loss 0.649769
# epoch 49, run 0, loss 0.626699
# epoch 49, run 10, loss 0.930164
# epoch 49, run 20, loss 1.22827
# epoch 49, run 30, loss 0.714066
# epoch 50, run 0, loss 0.600387
# epoch 50, run 10, loss 0.746032
# epoch 50, run 20, loss 1.11521
# epoch 50, run 30, loss 1.08996
# epoch 51, run 0, loss 0.634161
# epoch 51, run 10, loss 0.702992
# epoch 51, run 20, loss 1.3119
# epoch 51, run 30, loss 0.987752
# epoch 52, run 0, loss 0.797304
# epoch 52, run 10, loss 0.99625
# epoch 52, run 20, loss 1.35289
# epoch 52, run 30, loss 0.677418
# epoch 53, run 0, loss 0.950065
# epoch 53, run 10, loss 1.22629
# epoch 53, run 20, loss 1.13134
# epoch 53, run 30, loss 0.912894
# epoch 54, run 0, loss 0.948242
# epoch 54, run 10, loss 0.901574
# epoch 54, run 20, loss 0.596538
# epoch 54, run 30, loss 1.46905
# epoch 55, run 0, loss 0.720573
# epoch 55, run 10, loss 0.62057
# epoch 55, run 20, loss 0.576955
# epoch 55, run 30, loss 1.17756
# epoch 56, run 0, loss 0.934703
# epoch 56, run 10, loss 0.652393
# epoch 56, run 20, loss 0.72932
# epoch 56, run 30, loss 0.9931
# epoch 57, run 0, loss 1.42447
# epoch 57, run 10, loss 0.59824
# epoch 57, run 20, loss 0.934655
# epoch 57, run 30, loss 1.00845
# epoch 58, run 0, loss 1.0244
# epoch 58, run 10, loss 0.419336
# epoch 58, run 20, loss 1.0332
# epoch 58, run 30, loss 0.959963
# epoch 59, run 0, loss 1.04329
# epoch 59, run 10, loss 0.574542
# epoch 59, run 20, loss 0.994523
# epoch 59, run 30, loss 1.01531
# epoch 60, run 0, loss 0.840819
# epoch 60, run 10, loss 0.783103
# epoch 60, run 20, loss 0.832278
# epoch 60, run 30, loss 1.16813
# epoch 61, run 0, loss 0.905428
# epoch 61, run 10, loss 0.629338
# epoch 61, run 20, loss 0.728029
# epoch 61, run 30, loss 1.22874
# epoch 62, run 0, loss 0.998692
# epoch 62, run 10, loss 0.60776
# epoch 62, run 20, loss 0.749652
# epoch 62, run 30, loss 1.02052
# epoch 63, run 0, loss 1.14422
# epoch 63, run 10, loss 0.44297
# epoch 63, run 20, loss 0.79719
# epoch 63, run 30, loss 1.18641
# epoch 64, run 0, loss 1.11793
# epoch 64, run 10, loss 0.747391
# epoch 64, run 20, loss 0.824323
# epoch 64, run 30, loss 1.12885
# epoch 65, run 0, loss 1.0605
# epoch 65, run 10, loss 0.68211
# epoch 65, run 20, loss 0.8905
# epoch 65, run 30, loss 0.988242
# epoch 66, run 0, loss 1.03917
# epoch 66, run 10, loss 0.665581
# epoch 66, run 20, loss 0.843084
# epoch 66, run 30, loss 1.20814
# epoch 67, run 0, loss 1.02339
# epoch 67, run 10, loss 0.528205
# epoch 67, run 20, loss 0.775263
# epoch 67, run 30, loss 1.09432
# epoch 68, run 0, loss 1.0732
# epoch 68, run 10, loss 0.603714
# epoch 68, run 20, loss 0.694164
# epoch 68, run 30, loss 1.09513
# epoch 69, run 0, loss 1.11911
# epoch 69, run 10, loss 0.630175
# epoch 69, run 20, loss 0.746996
# epoch 69, run 30, loss 1.12216
# epoch 70, run 0, loss 0.991991
# epoch 70, run 10, loss 0.882931
# epoch 70, run 20, loss 1.13465
# epoch 70, run 30, loss 0.99657
# epoch 71, run 0, loss 1.13178
# epoch 71, run 10, loss 0.912238
# epoch 71, run 20, loss 0.778316
# epoch 71, run 30, loss 0.772985
# epoch 72, run 0, loss 1.1686
# epoch 72, run 10, loss 0.664984
# epoch 72, run 20, loss 0.552051
# epoch 72, run 30, loss 0.557903
# epoch 73, run 0, loss 0.963053
# epoch 73, run 10, loss 0.87271
# epoch 73, run 20, loss 0.593873
# epoch 73, run 30, loss 0.681848
# epoch 74, run 0, loss 0.624916
# epoch 74, run 10, loss 1.27339
# epoch 74, run 20, loss 0.656544
# epoch 74, run 30, loss 0.747277
# epoch 75, run 0, loss 0.572649
# epoch 75, run 10, loss 1.0581
# epoch 75, run 20, loss 0.430969
# epoch 75, run 30, loss 0.776655
# epoch 76, run 0, loss 0.663036
# epoch 76, run 10, loss 0.88134
# epoch 76, run 20, loss 0.550437
# epoch 76, run 30, loss 0.881819
# epoch 77, run 0, loss 0.82062
# epoch 77, run 10, loss 0.876963
# epoch 77, run 20, loss 0.755699
# epoch 77, run 30, loss 0.780729
# epoch 78, run 0, loss 0.961731
# epoch 78, run 10, loss 0.864905
# epoch 78, run 20, loss 0.577174
# epoch 78, run 30, loss 0.636661
# epoch 79, run 0, loss 0.86425
# epoch 79, run 10, loss 0.951147
# epoch 79, run 20, loss 0.546615
# epoch 79, run 30, loss 0.77464
# epoch 80, run 0, loss 0.779563
# epoch 80, run 10, loss 1.05927
# epoch 80, run 20, loss 0.479125
# epoch 80, run 30, loss 0.787775
# epoch 81, run 0, loss 0.710002
# epoch 81, run 10, loss 1.10285
# epoch 81, run 20, loss 0.580456
# epoch 81, run 30, loss 0.62897
# epoch 82, run 0, loss 0.666135
# epoch 82, run 10, loss 0.954697
# epoch 82, run 20, loss 0.700479
# epoch 82, run 30, loss 0.646525
# epoch 83, run 0, loss 0.685948
# epoch 83, run 10, loss 1.06803
# epoch 83, run 20, loss 0.549219
# epoch 83, run 30, loss 0.801159
# epoch 84, run 0, loss 0.730332
# epoch 84, run 10, loss 1.03131
# epoch 84, run 20, loss 0.48441
# epoch 84, run 30, loss 0.620886
# epoch 85, run 0, loss 0.822916
# epoch 85, run 10, loss 0.925557
# epoch 85, run 20, loss 0.503936
# epoch 85, run 30, loss 0.570607
# epoch 86, run 0, loss 0.808957
# epoch 86, run 10, loss 1.10427
# epoch 86, run 20, loss 0.662575
# epoch 86, run 30, loss 0.550132
# epoch 87, run 0, loss 0.701053
# epoch 87, run 10, loss 1.03892
# epoch 87, run 20, loss 0.773494
# epoch 87, run 30, loss 0.885142
# epoch 88, run 0, loss 0.621716
# epoch 88, run 10, loss 0.890581
# epoch 88, run 20, loss 0.745278
# epoch 88, run 30, loss 0.73352
# epoch 89, run 0, loss 0.695109
# epoch 89, run 10, loss 1.0139
# epoch 89, run 20, loss 0.637099
# epoch 89, run 30, loss 0.52144
# epoch 90, run 0, loss 0.984908
# epoch 90, run 10, loss 0.870787
# epoch 90, run 20, loss 0.714899
# epoch 90, run 30, loss 0.564672
# epoch 91, run 0, loss 0.68162
# epoch 91, run 10, loss 0.693114
# epoch 91, run 20, loss 1.14355
# epoch 91, run 30, loss 0.608936
# epoch 92, run 0, loss 0.558348
# epoch 92, run 10, loss 0.542189
# epoch 92, run 20, loss 0.950933
# epoch 92, run 30, loss 0.445371
# epoch 93, run 0, loss 0.574672
# epoch 93, run 10, loss 0.636121
# epoch 93, run 20, loss 0.841149
# epoch 93, run 30, loss 0.434336
# epoch 94, run 0, loss 0.608042
# epoch 94, run 10, loss 0.66717
# epoch 94, run 20, loss 0.918379
# epoch 94, run 30, loss 0.678632
# epoch 95, run 0, loss 0.382302
# epoch 95, run 10, loss 0.724363
# epoch 95, run 20, loss 0.77033
# epoch 95, run 30, loss 0.467228
# epoch 96, run 0, loss 0.496346
# epoch 96, run 10, loss 0.898851
# epoch 96, run 20, loss 0.878055
# epoch 96, run 30, loss 0.48467
# epoch 97, run 0, loss 0.653526
# epoch 97, run 10, loss 0.733301
# epoch 97, run 20, loss 0.878697
# epoch 97, run 30, loss 0.457902
# epoch 98, run 0, loss 0.565814
# epoch 98, run 10, loss 0.682134
# epoch 98, run 20, loss 0.924715
# epoch 98, run 30, loss 0.463408
# epoch 99, run 0, loss 0.520928
# epoch 99, run 10, loss 0.725082
# epoch 99, run 20, loss 0.862839
# epoch 99, run 30, loss 0.617654
# epoch 100, run 0, loss 0.454615
# epoch 100, run 10, loss 0.691469
# epoch 100, run 20, loss 0.878731
# epoch 100, run 30, loss 0.580826
# epoch 101, run 0, loss 0.554217
# epoch 101, run 10, loss 0.566007
# epoch 101, run 20, loss 1.033
# epoch 101, run 30, loss 0.514416
# epoch 102, run 0, loss 0.647124
# epoch 102, run 10, loss 0.600961
# epoch 102, run 20, loss 0.815416
# epoch 102, run 30, loss 0.504695
# epoch 103, run 0, loss 0.493748
# epoch 103, run 10, loss 0.726504
# epoch 103, run 20, loss 0.89332
# epoch 103, run 30, loss 0.640976
# epoch 104, run 0, loss 0.434456
# epoch 104, run 10, loss 0.586845
# epoch 104, run 20, loss 1.11232
# epoch 104, run 30, loss 0.64376
# epoch 105, run 0, loss 0.478777
# epoch 105, run 10, loss 0.536346
# epoch 105, run 20, loss 0.902586
# epoch 105, run 30, loss 0.625637
# epoch 106, run 0, loss 0.607043
# epoch 106, run 10, loss 0.477118
# epoch 106, run 20, loss 0.848745
# epoch 106, run 30, loss 0.663715
# epoch 107, run 0, loss 0.719836
# epoch 107, run 10, loss 0.77675
# epoch 107, run 20, loss 0.841145
# epoch 107, run 30, loss 0.632029
# epoch 108, run 0, loss 0.621869
# epoch 108, run 10, loss 0.664888
# epoch 108, run 20, loss 0.711797
# epoch 108, run 30, loss 0.882163
# epoch 109, run 0, loss 0.615645
# epoch 109, run 10, loss 0.492835
# epoch 109, run 20, loss 0.51428
# epoch 109, run 30, loss 0.925167
# epoch 110, run 0, loss 0.671358
# epoch 110, run 10, loss 0.527019
# epoch 110, run 20, loss 0.568785
# epoch 110, run 30, loss 0.711276
# epoch 111, run 0, loss 1.07206
# epoch 111, run 10, loss 0.561422
# epoch 111, run 20, loss 0.58229
# epoch 111, run 30, loss 0.725016
# epoch 112, run 0, loss 0.882936
# epoch 112, run 10, loss 0.367633
# epoch 112, run 20, loss 0.692141
# epoch 112, run 30, loss 0.650565
# epoch 113, run 0, loss 0.745029
# epoch 113, run 10, loss 0.409784
# epoch 113, run 20, loss 0.850571
# epoch 113, run 30, loss 0.678411
# epoch 114, run 0, loss 0.804156
# epoch 114, run 10, loss 0.620346
# epoch 114, run 20, loss 0.758127
# epoch 114, run 30, loss 0.839202
# epoch 115, run 0, loss 0.71895
# epoch 115, run 10, loss 0.436074
# epoch 115, run 20, loss 0.611754
# epoch 115, run 30, loss 0.831983
# epoch 116, run 0, loss 0.795809
# epoch 116, run 10, loss 0.449039
# epoch 116, run 20, loss 0.576337
# epoch 116, run 30, loss 0.901522
# epoch 117, run 0, loss 0.824442
# epoch 117, run 10, loss 0.370414
# epoch 117, run 20, loss 0.474605
# epoch 117, run 30, loss 0.943385
# epoch 118, run 0, loss 0.839769
# epoch 118, run 10, loss 0.445162
# epoch 118, run 20, loss 0.507228
# epoch 118, run 30, loss 0.906643
# epoch 119, run 0, loss 0.80854
# epoch 119, run 10, loss 0.580614
# epoch 119, run 20, loss 0.514365
# epoch 119, run 30, loss 0.837479
# epoch 120, run 0, loss 0.839082
# epoch 120, run 10, loss 0.540981
# epoch 120, run 20, loss 0.827975
# epoch 120, run 30, loss 0.805082
# epoch 121, run 0, loss 0.955996
# epoch 121, run 10, loss 0.498334
# epoch 121, run 20, loss 0.632991
# epoch 121, run 30, loss 0.917803
# epoch 122, run 0, loss 0.777451
# epoch 122, run 10, loss 0.465872
# epoch 122, run 20, loss 0.513778
# epoch 122, run 30, loss 0.730295
# epoch 123, run 0, loss 0.850494
# epoch 123, run 10, loss 0.54705
# epoch 123, run 20, loss 0.425556
# epoch 123, run 30, loss 0.796827
# epoch 124, run 0, loss 1.01613
# epoch 124, run 10, loss 0.588295
# epoch 124, run 20, loss 0.648781
# epoch 124, run 30, loss 0.799207
# epoch 125, run 0, loss 0.763076
# epoch 125, run 10, loss 0.551266
# epoch 125, run 20, loss 0.764458
# epoch 125, run 30, loss 0.710308
# epoch 126, run 0, loss 0.784737
# epoch 126, run 10, loss 0.567939
# epoch 126, run 20, loss 0.51158
# epoch 126, run 30, loss 0.603677
# epoch 127, run 0, loss 0.776271
# epoch 127, run 10, loss 0.589137
# epoch 127, run 20, loss 0.542975
# epoch 127, run 30, loss 0.508438
# epoch 128, run 0, loss 0.664413
# epoch 128, run 10, loss 0.811203
# epoch 128, run 20, loss 0.526901
# epoch 128, run 30, loss 0.480273
# epoch 129, run 0, loss 0.496651
# epoch 129, run 10, loss 0.880601
# epoch 129, run 20, loss 0.444075
# epoch 129, run 30, loss 0.728489
# epoch 130, run 0, loss 0.55327
# epoch 130, run 10, loss 0.649457
# epoch 130, run 20, loss 0.283801
# epoch 130, run 30, loss 0.709493
# epoch 131, run 0, loss 0.574847
# epoch 131, run 10, loss 0.653595
# epoch 131, run 20, loss 0.488542
# epoch 131, run 30, loss 0.707056
# epoch 132, run 0, loss 0.638413
# epoch 132, run 10, loss 0.616864
# epoch 132, run 20, loss 0.440439
# epoch 132, run 30, loss 0.620657
# epoch 133, run 0, loss 0.725874
# epoch 133, run 10, loss 0.656222
# epoch 133, run 20, loss 0.484758
# epoch 133, run 30, loss 0.714173
# epoch 134, run 0, loss 0.712297
# epoch 134, run 10, loss 0.77258
# epoch 134, run 20, loss 0.464966
# epoch 134, run 30, loss 0.488272
# epoch 135, run 0, loss 0.582929
# epoch 135, run 10, loss 0.77306
# epoch 135, run 20, loss 0.442134
# epoch 135, run 30, loss 0.505964
# epoch 136, run 0, loss 0.550786
# epoch 136, run 10, loss 0.822286
# epoch 136, run 20, loss 0.573344
# epoch 136, run 30, loss 0.585854
# epoch 137, run 0, loss 0.427541
# epoch 137, run 10, loss 0.764033
# epoch 137, run 20, loss 0.571415
# epoch 137, run 30, loss 0.711662
# epoch 138, run 0, loss 0.468735
# epoch 138, run 10, loss 0.806747
# epoch 138, run 20, loss 0.426737
# epoch 138, run 30, loss 0.689513
# epoch 139, run 0, loss 0.496283
# epoch 139, run 10, loss 0.795791
# epoch 139, run 20, loss 0.481712
# epoch 139, run 30, loss 0.506409
# epoch 140, run 0, loss 0.807088
# epoch 140, run 10, loss 0.755892
# epoch 140, run 20, loss 0.502314
# epoch 140, run 30, loss 0.344719
# epoch 141, run 0, loss 0.544205
# epoch 141, run 10, loss 0.848034
# epoch 141, run 20, loss 0.520263
# epoch 141, run 30, loss 0.531831
# epoch 142, run 0, loss 0.502816
# epoch 142, run 10, loss 0.716185
# epoch 142, run 20, loss 0.528885
# epoch 142, run 30, loss 0.686891
# epoch 143, run 0, loss 0.367968
# epoch 143, run 10, loss 0.729637
# epoch 143, run 20, loss 0.628628
# epoch 143, run 30, loss 0.502425
# epoch 144, run 0, loss 0.578301
# epoch 144, run 10, loss 0.758089
# epoch 144, run 20, loss 0.557367
# epoch 144, run 30, loss 0.420608
# epoch 145, run 0, loss 0.695237
# epoch 145, run 10, loss 0.663255
# epoch 145, run 20, loss 0.579561
# epoch 145, run 30, loss 0.502889
# epoch 146, run 0, loss 0.474124
# epoch 146, run 10, loss 0.486477
# epoch 146, run 20, loss 0.852109
# epoch 146, run 30, loss 0.403366
# epoch 147, run 0, loss 0.461153
# epoch 147, run 10, loss 0.476804
# epoch 147, run 20, loss 0.654981
# epoch 147, run 30, loss 0.323727
# epoch 148, run 0, loss 0.512189
# epoch 148, run 10, loss 0.440068
# epoch 148, run 20, loss 0.556244
# epoch 148, run 30, loss 0.399182
# epoch 149, run 0, loss 0.413157
# epoch 149, run 10, loss 0.680826
# epoch 149, run 20, loss 0.518405
# epoch 149, run 30, loss 0.46324
# epoch 150, run 0, loss 0.320737
# epoch 150, run 10, loss 0.679768
# epoch 150, run 20, loss 0.652022
# epoch 150, run 30, loss 0.489115
# epoch 151, run 0, loss 0.451973
# epoch 151, run 10, loss 0.641121
# epoch 151, run 20, loss 0.745204
# epoch 151, run 30, loss 0.453458
# epoch 152, run 0, loss 0.409013
# epoch 152, run 10, loss 0.595872
# epoch 152, run 20, loss 0.721586
# epoch 152, run 30, loss 0.290949
# epoch 153, run 0, loss 0.472947
# epoch 153, run 10, loss 0.680003
# epoch 153, run 20, loss 0.72223
# epoch 153, run 30, loss 0.548019
# epoch 154, run 0, loss 0.421128
# epoch 154, run 10, loss 0.464648
# epoch 154, run 20, loss 0.810515
# epoch 154, run 30, loss 0.515925
# epoch 155, run 0, loss 0.417212
# epoch 155, run 10, loss 0.438149
# epoch 155, run 20, loss 0.758902
# epoch 155, run 30, loss 0.440131
# epoch 156, run 0, loss 0.540662
# epoch 156, run 10, loss 0.473643
# epoch 156, run 20, loss 0.755014
# epoch 156, run 30, loss 0.41883
# epoch 157, run 0, loss 0.542557
# epoch 157, run 10, loss 0.692075
# epoch 157, run 20, loss 0.706222
# epoch 157, run 30, loss 0.454057
# epoch 158, run 0, loss 0.401125
# epoch 158, run 10, loss 0.637422
# epoch 158, run 20, loss 0.825822
# epoch 158, run 30, loss 0.476006
# epoch 159, run 0, loss 0.464757
# epoch 159, run 10, loss 0.474679
# epoch 159, run 20, loss 0.685766
# epoch 159, run 30, loss 0.525371
# epoch 160, run 0, loss 0.474846
# epoch 180, run 30, loss 0.501529
# epoch 181, run 0, loss 0.612696
# epoch 181, run 10, loss 0.46177
# epoch 181, run 20, loss 0.417781
# epoch 181, run 30, loss 0.408232
# epoch 182, run 0, loss 0.553227
# epoch 182, run 10, loss 0.471934
# epoch 182, run 20, loss 0.475039
# epoch 182, run 30, loss 0.396782
# epoch 183, run 0, loss 0.494848
# epoch 183, run 10, loss 0.756414
# epoch 183, run 20, loss 0.41102
# epoch 183, run 30, loss 0.504882
# epoch 184, run 0, loss 0.414595
# epoch 184, run 10, loss 0.633162
# epoch 184, run 20, loss 0.25957
# epoch 184, run 30, loss 0.515104
# epoch 185, run 0, loss 0.373673
# epoch 185, run 10, loss 0.475795
# epoch 185, run 20, loss 0.375207
# epoch 185, run 30, loss 0.581556
# epoch 186, run 0, loss 0.529967
# epoch 186, run 10, loss 0.498603
# epoch 186, run 20, loss 0.436588
# epoch 186, run 30, loss 0.54855
# epoch 187, run 0, loss 0.628394
# epoch 187, run 10, loss 0.645529
# epoch 187, run 20, loss 0.507188
# epoch 187, run 30, loss 0.549637
# epoch 188, run 0, loss 0.53144
# epoch 188, run 10, loss 0.677222
# epoch 188, run 20, loss 0.392695
# epoch 188, run 30, loss 0.535756
# epoch 189, run 0, loss 0.467664
# epoch 189, run 10, loss 0.670526
# epoch 189, run 20, loss 0.290556
# epoch 189, run 30, loss 0.41523
# epoch 190, run 0, loss 0.567871
# epoch 190, run 10, loss 0.639767
# epoch 190, run 20, loss 0.460707
# epoch 190, run 30, loss 0.375726
# epoch 191, run 0, loss 0.401883
# epoch 191, run 10, loss 0.677402
# epoch 191, run 20, loss 0.484878
# epoch 191, run 30, loss 0.666289
# epoch 192, run 0, loss 0.373938
# epoch 192, run 10, loss 0.690495
# epoch 192, run 20, loss 0.377508
# epoch 192, run 30, loss 0.625408
# epoch 193, run 0, loss 0.454947
# epoch 193, run 10, loss 0.693735
# epoch 193, run 20, loss 0.354502
# epoch 193, run 30, loss 0.504074
# epoch 194, run 0, loss 0.607032
# epoch 194, run 10, loss 0.663065
# epoch 194, run 20, loss 0.374888
# epoch 194, run 30, loss 0.380691
# epoch 195, run 0, loss 0.634527
# epoch 195, run 10, loss 0.693248
# epoch 195, run 20, loss 0.388647
# epoch 195, run 30, loss 0.284534
# epoch 196, run 0, loss 0.451128
# epoch 196, run 10, loss 0.672717
# epoch 196, run 20, loss 0.458363
# epoch 196, run 30, loss 0.473261
# epoch 197, run 0, loss 0.332023
# epoch 197, run 10, loss 0.597074
# epoch 197, run 20, loss 0.385665
# epoch 197, run 30, loss 0.478763
# epoch 198, run 0, loss 0.367785
# epoch 198, run 10, loss 0.595915
# epoch 198, run 20, loss 0.431277
# epoch 198, run 30, loss 0.336248
# epoch 199, run 0, loss 0.508989
# epoch 199, run 10, loss 0.575035
# epoch 199, run 20, loss 0.422295
# epoch 199, run 30, loss 0.393657
# epoch 200, run 0, loss 0.402576
# epoch 200, run 10, loss 0.41395
# epoch 200, run 20, loss 0.697468
# epoch 200, run 30, loss 0.413911
# epoch 201, run 0, loss 0.396853
# epoch 201, run 10, loss 0.380696
# epoch 201, run 20, loss 0.627466
# epoch 201, run 30, loss 0.250265
# epoch 202, run 0, loss 0.450756
# epoch 202, run 10, loss 0.345199
# epoch 202, run 20, loss 0.49502
# epoch 202, run 30, loss 0.33122
# epoch 203, run 0, loss 0.376101
# epoch 203, run 10, loss 0.472277
# epoch 203, run 20, loss 0.508653
# epoch 203, run 30, loss 0.429915
# epoch 204, run 0, loss 0.200201
# epoch 204, run 10, loss 0.472986
# epoch 204, run 20, loss 0.605814
# epoch 204, run 30, loss 0.36399
# epoch 205, run 0, loss 0.358268
# epoch 205, run 10, loss 0.513045
# epoch 205, run 20, loss 0.588525
# epoch 205, run 30, loss 0.341679
# epoch 206, run 0, loss 0.399725
# epoch 206, run 10, loss 0.49411
# epoch 206, run 20, loss 0.574868
# epoch 206, run 30, loss 0.257714
# epoch 207, run 0, loss 0.462104
# epoch 207, run 10, loss 0.524099
# epoch 207, run 20, loss 0.598848
# epoch 207, run 30, loss 0.344814
# epoch 208, run 0, loss 0.363789
# epoch 208, run 10, loss 0.479733
# epoch 208, run 20, loss 0.609145
# epoch 208, run 30, loss 0.461085
# epoch 209, run 0, loss 0.241826
# epoch 209, run 10, loss 0.377785
# epoch 209, run 20, loss 0.656209
# epoch 209, run 30, loss 0.33028
# epoch 210, run 0, loss 0.46205
# epoch 210, run 10, loss 0.352445
# epoch 210, run 20, loss 0.624647
# epoch 210, run 30, loss 0.375904
# epoch 211, run 0, loss 0.43126
# epoch 211, run 10, loss 0.619321
# epoch 211, run 20, loss 0.629884
# epoch 211, run 30, loss 0.312424
# epoch 212, run 0, loss 0.36417
# epoch 212, run 10, loss 0.603823
# epoch 212, run 20, loss 0.594636
# epoch 212, run 30, loss 0.432086
# epoch 213, run 0, loss 0.309035
# epoch 213, run 10, loss 0.465869
# epoch 213, run 20, loss 0.630739
# epoch 213, run 30, loss 0.381617
# epoch 214, run 0, loss 0.339179
# epoch 214, run 10, loss 0.344612
# epoch 214, run 20, loss 0.475254
# epoch 214, run 30, loss 0.360919
# epoch 215, run 0, loss 0.361786
# epoch 215, run 10, loss 0.26392
# epoch 215, run 20, loss 0.508267
# epoch 215, run 30, loss 0.387653
# epoch 216, run 0, loss 0.415994
# epoch 216, run 10, loss 0.448338
# epoch 216, run 20, loss 0.534262
# epoch 216, run 30, loss 0.423685
# epoch 217, run 0, loss 0.335994
# epoch 217, run 10, loss 0.441565
# epoch 217, run 20, loss 0.452948
# epoch 217, run 30, loss 0.580369
# epoch 218, run 0, loss 0.370575
# epoch 218, run 10, loss 0.349736
# epoch 218, run 20, loss 0.369899
# epoch 218, run 30, loss 0.63145
# epoch 219, run 0, loss 0.398804
# epoch 219, run 10, loss 0.369106
# epoch 219, run 20, loss 0.407887
# epoch 219, run 30, loss 0.458073
# epoch 220, run 0, loss 0.653158
# epoch 220, run 10, loss 0.382484
# epoch 220, run 20, loss 0.420412
# epoch 220, run 30, loss 0.430768
# epoch 221, run 0, loss 0.581384
# epoch 221, run 10, loss 0.23543
# epoch 221, run 20, loss 0.450015
# epoch 242, run 10, loss 0.52081
# epoch 242, run 20, loss 0.323447
# epoch 242, run 30, loss 0.420118
# epoch 243, run 0, loss 0.486042
# epoch 243, run 10, loss 0.498461
# epoch 243, run 20, loss 0.22015
# epoch 243, run 30, loss 0.327494
# epoch 244, run 0, loss 0.387059
# epoch 244, run 10, loss 0.526951
# epoch 244, run 20, loss 0.315771
# epoch 244, run 30, loss 0.317911
# epoch 245, run 0, loss 0.410385
# epoch 245, run 10, loss 0.577795
# epoch 245, run 20, loss 0.399829
# epoch 245, run 30, loss 0.316022
# epoch 246, run 0, loss 0.30986
# epoch 246, run 10, loss 0.513561
# epoch 246, run 20, loss 0.326861
# epoch 246, run 30, loss 0.593461
# epoch 247, run 0, loss 0.312274
# epoch 247, run 10, loss 0.577871
# epoch 247, run 20, loss 0.297783
# epoch 247, run 30, loss 0.46672
# epoch 248, run 0, loss 0.429078
# epoch 248, run 10, loss 0.564252
# epoch 248, run 20, loss 0.297027
# epoch 248, run 30, loss 0.32355
# epoch 249, run 0, loss 0.597205
# epoch 249, run 10, loss 0.488661
# epoch 249, run 20, loss 0.359353
# epoch 249, run 30, loss 0.271398
# epoch 250, run 0, loss 0.3309
# epoch 250, run 10, loss 0.526295
# epoch 250, run 20, loss 0.33367
# epoch 250, run 30, loss 0.327888
# epoch 251, run 0, loss 0.340887
# epoch 251, run 10, loss 0.402802
# epoch 251, run 20, loss 0.292392
# epoch 251, run 30, loss 0.371147
# epoch 252, run 0, loss 0.250722
# epoch 252, run 10, loss 0.426515
# epoch 252, run 20, loss 0.36754
# epoch 252, run 30, loss 0.298153
# epoch 253, run 0, loss 0.360243
# epoch 253, run 10, loss 0.470901
# epoch 253, run 20, loss 0.340535
# epoch 253, run 30, loss 0.353316
# epoch 254, run 0, loss 0.350792
# epoch 254, run 10, loss 0.398438
# epoch 254, run 20, loss 0.398308
# epoch 254, run 30, loss 0.409234
# epoch 255, run 0, loss 0.311881
# epoch 255, run 10, loss 0.300476
# epoch 255, run 20, loss 0.587943
# epoch 255, run 30, loss 0.259503
# epoch 256, run 0, loss 0.340885
# epoch 256, run 10, loss 0.32674
# epoch 256, run 20, loss 0.49768
# epoch 256, run 30, loss 0.223731
# epoch 257, run 0, loss 0.367554
# epoch 257, run 10, loss 0.316702
# epoch 257, run 20, loss 0.344436
# epoch 257, run 30, loss 0.273108
# epoch 258, run 0, loss 0.238225
# epoch 258, run 10, loss 0.403979
# epoch 258, run 20, loss 0.398512
# epoch 258, run 30, loss 0.300055
# epoch 259, run 0, loss 0.247078
# epoch 259, run 10, loss 0.427003
# epoch 259, run 20, loss 0.521668
# epoch 259, run 30, loss 0.370675
# epoch 260, run 0, loss 0.306784
# epoch 260, run 10, loss 0.386658
# epoch 260, run 20, loss 0.544016
# epoch 260, run 30, loss 0.314995
# epoch 261, run 0, loss 0.257071
# epoch 261, run 10, loss 0.366734
# epoch 261, run 20, loss 0.502169
# epoch 261, run 30, loss 0.199641
# epoch 262, run 0, loss 0.288487
# epoch 262, run 10, loss 0.397649
# epoch 262, run 20, loss 0.469414
# epoch 262, run 30, loss 0.388902
# epoch 263, run 0, loss 0.210443
# epoch 263, run 10, loss 0.300598
# epoch 263, run 20, loss 0.525363
# epoch 263, run 30, loss 0.32192
# epoch 264, run 0, loss 0.286403
# epoch 264, run 10, loss 0.300532
# epoch 264, run 20, loss 0.469553
# epoch 264, run 30, loss 0.279294
# epoch 265, run 0, loss 0.370531
# epoch 265, run 10, loss 0.293182
# epoch 265, run 20, loss 0.566296
# epoch 265, run 30, loss 0.278109
# epoch 266, run 0, loss 0.275357
# epoch 266, run 10, loss 0.549197
# epoch 266, run 20, loss 0.446104
# epoch 266, run 30, loss 0.275709
# epoch 267, run 0, loss 0.276723
# epoch 267, run 10, loss 0.437937
# epoch 267, run 20, loss 0.50889
# epoch 267, run 30, loss 0.320277
# epoch 268, run 0, loss 0.271078
# epoch 268, run 10, loss 0.300942
# epoch 268, run 20, loss 0.420507
# epoch 268, run 30, loss 0.294517
# epoch 269, run 0, loss 0.332442
# epoch 269, run 10, loss 0.273534
# epoch 269, run 20, loss 0.338153
# epoch 269, run 30, loss 0.324188
# epoch 270, run 0, loss 0.31592
# epoch 270, run 10, loss 0.307197
# epoch 270, run 20, loss 0.439077
# epoch 270, run 30, loss 0.327261
# epoch 271, run 0, loss 0.248977
# epoch 271, run 10, loss 0.342768
# epoch 271, run 20, loss 0.344826
# epoch 271, run 30, loss 0.325679
# epoch 272, run 0, loss 0.341509
# epoch 272, run 10, loss 0.275196
# epoch 272, run 20, loss 0.335013
# epoch 272, run 30, loss 0.59793
# epoch 273, run 0, loss 0.323367
# epoch 273, run 10, loss 0.341776
# epoch 273, run 20, loss 0.291014
# epoch 273, run 30, loss 0.443538
# epoch 274, run 0, loss 0.428463
# epoch 274, run 10, loss 0.378929
# epoch 274, run 20, loss 0.248778
# epoch 274, run 30, loss 0.314678
# epoch 275, run 0, loss 0.542673
# epoch 275, run 10, loss 0.256357
# epoch 275, run 20, loss 0.398672
# epoch 275, run 30, loss 0.362035
# epoch 276, run 0, loss 0.473571
# epoch 276, run 10, loss 0.199985
# epoch 276, run 20, loss 0.363623
# epoch 276, run 30, loss 0.509266
# epoch 277, run 0, loss 0.334139
# epoch 277, run 10, loss 0.255166
# epoch 277, run 20, loss 0.325259
# epoch 277, run 30, loss 0.536131
# epoch 278, run 0, loss 0.388411
# epoch 278, run 10, loss 0.285713
# epoch 278, run 20, loss 0.333951
# epoch 278, run 30, loss 0.509919
# epoch 279, run 0, loss 0.421649
# epoch 279, run 10, loss 0.352103
# epoch 279, run 20, loss 0.40671
# epoch 279, run 30, loss 0.433287
# epoch 280, run 0, loss 0.469775
# epoch 280, run 10, loss 0.292118
# epoch 280, run 20, loss 0.284394
# epoch 280, run 30, loss 0.462042
# epoch 281, run 0, loss 0.489729
# epoch 281, run 10, loss 0.18126
# epoch 281, run 20, loss 0.27462
# epoch 281, run 30, loss 0.400973
# epoch 282, run 0, loss 0.507981
# epoch 282, run 10, loss 0.371196
# epoch 282, run 20, loss 0.324385
# epoch 282, run 30, loss 0.510238
# epoch 283, run 0, loss 0.480444
# epoch 283, run 10, loss 0.292784
# epoch 283, run 20, loss 0.489505
# epoch 283, run 30, loss 0.515728
# epoch 284, run 0, loss 0.440629
# epoch 284, run 10, loss 0.247398
# epoch 284, run 20, loss 0.504391
# epoch 284, run 30, loss 0.430574
# epoch 285, run 0, loss 0.525914
# epoch 285, run 10, loss 0.258278
# epoch 285, run 20, loss 0.295695
# epoch 285, run 30, loss 0.408938
# epoch 286, run 0, loss 0.423208
# epoch 286, run 10, loss 0.253883
# epoch 286, run 20, loss 0.232142
# epoch 286, run 30, loss 0.34459
# epoch 287, run 0, loss 0.461806
# epoch 287, run 10, loss 0.28722
# epoch 287, run 20, loss 0.23886
# epoch 287, run 30, loss 0.389862
# epoch 288, run 0, loss 0.35836
# epoch 288, run 10, loss 0.26923
# epoch 288, run 20, loss 0.309929
# epoch 288, run 30, loss 0.372524
# epoch 289, run 0, loss 0.314802
# epoch 289, run 10, loss 0.305964
# epoch 289, run 20, loss 0.262955
# epoch 289, run 30, loss 0.237258
# epoch 290, run 0, loss 0.424481
# epoch 290, run 10, loss 0.30764
# epoch 290, run 20, loss 0.30567
# epoch 290, run 30, loss 0.243844
# epoch 291, run 0, loss 0.319427
# epoch 291, run 10, loss 0.308122
# epoch 291, run 20, loss 0.338926
# epoch 291, run 30, loss 0.249237
# epoch 292, run 0, loss 0.301303
# epoch 292, run 10, loss 0.55928
# epoch 292, run 20, loss 0.247603
# epoch 292, run 30, loss 0.333182
# epoch 293, run 0, loss 0.271081
# epoch 293, run 10, loss 0.437414
# epoch 293, run 20, loss 0.138597
# epoch 293, run 30, loss 0.32759
# epoch 294, run 0, loss 0.241664
# epoch 294, run 10, loss 0.293618
# epoch 294, run 20, loss 0.244683
# epoch 294, run 30, loss 0.295429
# epoch 295, run 0, loss 0.370827
# epoch 295, run 10, loss 0.329696
# epoch 295, run 20, loss 0.282823
# epoch 295, run 30, loss 0.350154
# epoch 296, run 0, loss 0.317095
# epoch 296, run 10, loss 0.487021
# epoch 296, run 20, loss 0.341643
# epoch 296, run 30, loss 0.399374
# epoch 297, run 0, loss 0.28609
# epoch 297, run 10, loss 0.479692
# epoch 297, run 20, loss 0.280659
# epoch 297, run 30, loss 0.306187
# epoch 298, run 0, loss 0.300826
# epoch 298, run 10, loss 0.478393
# epoch 298, run 20, loss 0.150269
# epoch 298, run 30, loss 0.238358
# epoch 299, run 0, loss 0.398807
# epoch 299, run 10, loss 0.394845
# epoch 299, run 20, loss 0.385995
# epoch 299, run 30, loss 0.277336
# epoch 300, run 0, loss 0.262234
# epoch 300, run 10, loss 0.438046
# epoch 300, run 20, loss 0.270145
# epoch 300, run 30, loss 0.487748
# epoch 301, run 0, loss 0.267383
# epoch 301, run 10, loss 0.387152
# epoch 301, run 20, loss 0.242394
# epoch 301, run 30, loss 0.467771
# epoch 302, run 0, loss 0.294866
# epoch 302, run 10, loss 0.47606
# epoch 302, run 20, loss 0.210311
# epoch 302, run 30, loss 0.31845
# epoch 303, run 0, loss 0.463495
# epoch 303, run 10, loss 0.475478
# epoch 303, run 20, loss 0.224966
# epoch 303, run 30, loss 0.207985
# epoch 304, run 0, loss 0.512581
# epoch 304, run 10, loss 0.390648
# epoch 304, run 20, loss 0.259107
# epoch 304, run 30, loss 0.204406
# epoch 305, run 0, loss 0.275991
# epoch 305, run 10, loss 0.363121
# epoch 305, run 20, loss 0.285105
# epoch 305, run 30, loss 0.270714
# epoch 306, run 0, loss 0.211999
# epoch 306, run 10, loss 0.311109
# epoch 306, run 20, loss 0.224838
# epoch 306, run 30, loss 0.288239
# epoch 307, run 0, loss 0.221846
# epoch 307, run 10, loss 0.361435
# epoch 307, run 20, loss 0.246276
# epoch 307, run 30, loss 0.237581
# epoch 308, run 0, loss 0.312965
# epoch 308, run 10, loss 0.34552
# epoch 308, run 20, loss 0.279369
# epoch 308, run 30, loss 0.30312
# epoch 309, run 0, loss 0.255647
# epoch 309, run 10, loss 0.218674
# epoch 309, run 20, loss 0.45582
# epoch 309, run 30, loss 0.243996
# epoch 310, run 0, loss 0.285528
# epoch 310, run 10, loss 0.220351
# epoch 310, run 20, loss 0.448
# epoch 310, run 30, loss 0.150359
# epoch 311, run 0, loss 0.307301
# epoch 311, run 10, loss 0.231657
# epoch 311, run 20, loss 0.260762
# epoch 311, run 30, loss 0.232526
# epoch 312, run 0, loss 0.210899
# epoch 312, run 10, loss 0.312284
# epoch 312, run 20, loss 0.280927
# epoch 312, run 30, loss 0.317025
# epoch 313, run 0, loss 0.139775
# epoch 313, run 10, loss 0.291403
# epoch 313, run 20, loss 0.446591
# epoch 313, run 30, loss 0.316323
# epoch 314, run 0, loss 0.23041
# epoch 314, run 10, loss 0.276986
# epoch 314, run 20, loss 0.423765
# epoch 314, run 30, loss 0.252485
# epoch 315, run 0, loss 0.262107
# epoch 315, run 10, loss 0.32025
# epoch 315, run 20, loss 0.396574
# epoch 315, run 30, loss 0.171364
# epoch 316, run 0, loss 0.299221
# epoch 316, run 10, loss 0.376476
# epoch 316, run 20, loss 0.368981
# epoch 316, run 30, loss 0.307389
# epoch 317, run 0, loss 0.26238
# epoch 317, run 10, loss 0.288833
# epoch 317, run 20, loss 0.390308
# epoch 317, run 30, loss 0.319713
# epoch 318, run 0, loss 0.136546
# epoch 318, run 10, loss 0.222138
# epoch 318, run 20, loss 0.440181
# epoch 318, run 30, loss 0.187134
# epoch 319, run 0, loss 0.35331
# epoch 319, run 10, loss 0.281429
# epoch 319, run 20, loss 0.449173
# epoch 319, run 30, loss 0.226346
# epoch 320, run 0, loss 0.200927
# epoch 320, run 10, loss 0.449057
# epoch 320, run 20, loss 0.46643
# epoch 320, run 30, loss 0.192046
# epoch 321, run 0, loss 0.221705
# epoch 321, run 10, loss 0.460677
# epoch 321, run 20, loss 0.39339
# epoch 321, run 30, loss 0.294167
# epoch 322, run 0, loss 0.196432
# epoch 322, run 10, loss 0.28985
# epoch 322, run 20, loss 0.346306
# epoch 322, run 30, loss 0.2591
# epoch 323, run 0, loss 0.206899
# epoch 323, run 10, loss 0.19099
# epoch 323, run 20, loss 0.257308
# epoch 323, run 30, loss 0.200194
# epoch 324, run 0, loss 0.236012
# epoch 324, run 10, loss 0.181909
# epoch 324, run 20, loss 0.307482
# epoch 324, run 30, loss 0.254585
# epoch 325, run 0, loss 0.250093
# epoch 325, run 10, loss 0.271506
# epoch 325, run 20, loss 0.329224
# epoch 325, run 30, loss 0.26332
# epoch 326, run 0, loss 0.245422
# epoch 326, run 10, loss 0.252209
# epoch 326, run 20, loss 0.247479
# epoch 326, run 30, loss 0.342267
# epoch 327, run 0, loss 0.241955
# epoch 327, run 10, loss 0.214355
# epoch 327, run 20, loss 0.206779
# epoch 327, run 30, loss 0.41618
# epoch 328, run 0, loss 0.249916
# epoch 328, run 10, loss 0.284607
# epoch 328, run 20, loss 0.237979
# epoch 328, run 30, loss 0.308359
# epoch 329, run 0, loss 0.419254
# epoch 329, run 10, loss 0.221108
# epoch 329, run 20, loss 0.273538
# epoch 329, run 30, loss 0.305123
# epoch 330, run 0, loss 0.421938
# epoch 330, run 10, loss 0.149547
# epoch 330, run 20, loss 0.275006
# epoch 330, run 30, loss 0.389976
# epoch 331, run 0, loss 0.237301
# epoch 331, run 10, loss 0.225733
# epoch 331, run 20, loss 0.270002
# epoch 331, run 30, loss 0.427594
# epoch 332, run 0, loss 0.25739
# epoch 332, run 10, loss 0.29528
# epoch 332, run 20, loss 0.285957
# epoch 332, run 30, loss 0.374856
# epoch 333, run 0, loss 0.424728
# epoch 333, run 10, loss 0.292116
# epoch 333, run 20, loss 0.265764
# epoch 333, run 30, loss 0.401471
# epoch 334, run 0, loss 0.40162
# epoch 334, run 10, loss 0.235289
# epoch 334, run 20, loss 0.292895
# epoch 334, run 30, loss 0.390646
# epoch 335, run 0, loss 0.370942
# epoch 335, run 10, loss 0.156484
# epoch 335, run 20, loss 0.187361
# epoch 335, run 30, loss 0.370914
# epoch 336, run 0, loss 0.330655
# epoch 336, run 10, loss 0.289494
# epoch 336, run 20, loss 0.227373
# epoch 336, run 30, loss 0.413497
# epoch 337, run 0, loss 0.356398
# epoch 337, run 10, loss 0.286632
# epoch 337, run 20, loss 0.325909
# epoch 337, run 30, loss 0.401172
# epoch 338, run 0, loss 0.398776
# epoch 338, run 10, loss 0.172574
# epoch 338, run 20, loss 0.432358
# epoch 338, run 30, loss 0.353593
# epoch 339, run 0, loss 0.411831
# epoch 339, run 10, loss 0.164976
# epoch 339, run 20, loss 0.240787
# epoch 339, run 30, loss 0.32505
# epoch 340, run 0, loss 0.437995
# epoch 340, run 10, loss 0.182096
# epoch 340, run 20, loss 0.196273
# epoch 340, run 30, loss 0.238653
# epoch 341, run 0, loss 0.362502
# epoch 341, run 10, loss 0.270578
# epoch 341, run 20, loss 0.18798
# epoch 341, run 30, loss 0.284125
# epoch 342, run 0, loss 0.32485
# epoch 342, run 10, loss 0.243124
# epoch 342, run 20, loss 0.212094
# epoch 342, run 30, loss 0.328029
# epoch 343, run 0, loss 0.19075
# epoch 343, run 10, loss 0.182081
# epoch 343, run 20, loss 0.205605
# epoch 343, run 30, loss 0.252096
# epoch 344, run 0, loss 0.289384
# epoch 344, run 10, loss 0.234189
# epoch 344, run 20, loss 0.204208
# epoch 344, run 30, loss 0.191951
# epoch 345, run 0, loss 0.294943
# epoch 345, run 10, loss 0.255677
# epoch 345, run 20, loss 0.262393
# epoch 345, run 30, loss 0.222097
# epoch 346, run 0, loss 0.210707
# epoch 346, run 10, loss 0.388517
# epoch 346, run 20, loss 0.218296
# epoch 346, run 30, loss 0.240878
# epoch 347, run 0, loss 0.192465
# epoch 347, run 10, loss 0.394521
# epoch 347, run 20, loss 0.149038
# epoch 347, run 30, loss 0.276915
# epoch 348, run 0, loss 0.219415
# epoch 348, run 10, loss 0.272097
# epoch 348, run 20, loss 0.215192
# epoch 348, run 30, loss 0.268782
# epoch 349, run 0, loss 0.252693
# epoch 349, run 10, loss 0.275757
# epoch 349, run 20, loss 0.229653
# epoch 349, run 30, loss 0.237788
# epoch 350, run 0, loss 0.253443
# epoch 350, run 10, loss 0.364268
# epoch 350, run 20, loss 0.174033
# epoch 350, run 30, loss 0.256962
# epoch 351, run 0, loss 0.258532
# epoch 351, run 10, loss 0.407362
# epoch 351, run 20, loss 0.215207
# epoch 351, run 30, loss 0.300173
# epoch 352, run 0, loss 0.260374
# epoch 352, run 10, loss 0.322373
# epoch 352, run 20, loss 0.130399
# epoch 352, run 30, loss 0.181755
# epoch 353, run 0, loss 0.292098
# epoch 353, run 10, loss 0.377927
# epoch 353, run 20, loss 0.207047
# epoch 353, run 30, loss 0.210354
# epoch 354, run 0, loss 0.274342
# epoch 354, run 10, loss 0.328799
# epoch 354, run 20, loss 0.265592
# epoch 354, run 30, loss 0.222663
# epoch 355, run 0, loss 0.171359
# epoch 355, run 10, loss 0.340908
# epoch 355, run 20, loss 0.176069
# epoch 355, run 30, loss 0.433519
# epoch 356, run 0, loss 0.212713
# epoch 356, run 10, loss 0.379945
# epoch 356, run 20, loss 0.191918
# epoch 356, run 30, loss 0.338749
# epoch 357, run 0, loss 0.301715
# epoch 357, run 10, loss 0.393131
# epoch 357, run 20, loss 0.182312
# epoch 357, run 30, loss 0.212119
# epoch 358, run 0, loss 0.378686
# epoch 358, run 10, loss 0.320911
# epoch 358, run 20, loss 0.237441
# epoch 358, run 30, loss 0.184113
# epoch 359, run 0, loss 0.223776
# epoch 359, run 10, loss 0.294295
# epoch 359, run 20, loss 0.210199
# epoch 359, run 30, loss 0.198523
# epoch 360, run 0, loss 0.183219
# epoch 360, run 10, loss 0.221211
# epoch 360, run 20, loss 0.156231
# epoch 360, run 30, loss 0.219021
# epoch 361, run 0, loss 0.175801
# epoch 361, run 10, loss 0.261787
# epoch 361, run 20, loss 0.226062
# epoch 361, run 30, loss 0.207639
# epoch 362, run 0, loss 0.195081
# epoch 362, run 10, loss 0.29723
# epoch 362, run 20, loss 0.241291
# epoch 362, run 30, loss 0.283049
# epoch 363, run 0, loss 0.188137
# epoch 363, run 10, loss 0.223577
# epoch 363, run 20, loss 0.282887
# epoch 363, run 30, loss 0.273718
# epoch 364, run 0, loss 0.189457
# epoch 364, run 10, loss 0.171742
# epoch 364, run 20, loss 0.381934
# epoch 364, run 30, loss 0.167201
# epoch 365, run 0, loss 0.244951
# epoch 1993, run 10, loss 0.000212049
# epoch 1993, run 20, loss 7.21003e-05
# epoch 1993, run 30, loss 6.41046e-05
# epoch 1994, run 0, loss 4.6169e-05
# epoch 1994, run 10, loss 0.000182845
# epoch 1994, run 20, loss 0.000108013
# epoch 1994, run 30, loss 6.71828e-05
# epoch 1995, run 0, loss 5.31068e-05
# epoch 1995, run 10, loss 0.000150461
# epoch 1995, run 20, loss 9.48828e-05
# epoch 1995, run 30, loss 4.24812e-05
# epoch 1996, run 0, loss 6.60064e-05
# epoch 1996, run 10, loss 0.000124004
# epoch 1996, run 20, loss 0.000107281
# epoch 1996, run 30, loss 2.81695e-05
# epoch 1997, run 0, loss 5.16681e-05
# epoch 1997, run 10, loss 6.23928e-05
# epoch 1997, run 20, loss 0.000117128
# epoch 1997, run 30, loss 3.0557e-05
# epoch 1998, run 0, loss 3.42099e-05
# epoch 1998, run 10, loss 9.62793e-05
# epoch 1998, run 20, loss 9.47673e-05
# epoch 1998, run 30, loss 2.44572e-05
# epoch 1999, run 0, loss 2.79166e-05
# epoch 1999, run 10, loss 9.0164e-05
# epoch 1999, run 20, loss 0.000153936
# epoch 1999, run 30, loss 4.65837e-05

# %% [markdown]
# ### Test

# %%
x_test, y_test = (test_doc_embed_with_class[0], test_doc_embed_with_class[1])
# Out:
# (250, 100)
# (250, 8)

# %%
epoch = 3000

# %%
init = tf.global_variables_initializer()
sess.run(init)

# %%
for i in range(epoch):
    xloss = 0
    acc = 0.0
    
    for j in range(total_batch):
        # need to incoporate y in the batches and expand to 8 classes 
        index, x_, y_ = next_batch(train_doc_embed_with_class, index, batch_size)
        _, xloss = sess.run([optimizer, loss], feed_dict={x: x_, y: y_})
        
        if j % 30 == 0:
            print("epoch %d, run %d, loss %g" % (i, j, xloss))
            
    if i % 100 == 0:
        acc = sess.run(accuracy, feed_dict={x:test_doc_embed_with_class[0], y:test_doc_embed_with_class[1]})
        print("Test acc: %g" % (acc * 100), end="")
        print("%")
        
save_path = saver.save(sess, "/tmp/test_model"+str(time.time())+".ckpt")
print("Model saved in file: %s" % save_path)
# Out:
# Validation acc: 27.2%
# Validation acc: 42.4%
# Validation acc: 47.6%
# Validation acc: 44.8%
# Validation acc: 42%
# Validation acc: 41.6%
# Validation acc: 44%
# Validation acc: 47.2%
# Validation acc: 41.6%
# Validation acc: 43.6%
# Validation acc: 42.8%
# Validation acc: 40%
# Validation acc: 40.8%
# Validation acc: 40.8%
# Validation acc: 40.4%
# Validation acc: 42.4%
# Validation acc: 41.2%
# Validation acc: 42.8%
# Validation acc: 41.6%
# Validation acc: 39.6%
# Validation acc: 42%
# Validation acc: 43.6%
# Validation acc: 43.6%
# Validation acc: 43.6%
# Validation acc: 43.6%
# Validation acc: 40.4%
# Validation acc: 40.8%
# Validation acc: 41.2%
# Validation acc: 43.6%
# Validation acc: 42.8%

# %% [markdown]
# ## Questions to answer

# %% [markdown]
# - Compare the learning curves of the model starting from random embeddings, starting from GloVe embeddings (http://nlp.stanford.edu/data/glove.6B.zip; 50 dimensions) or fixed to be the GloVe values. Training in batches is more stable (e.g. 50), which model works best on training vs. test? Which model works best on held-out accuracy?
# - What happens if you try alternative non-linearities (logistic sigmoid or ReLU instead of tanh)?
# - What happens if you add dropout to the network?
# - What happens if you vary the size of the hidden layer?
# - How would the code change if you wanted to add a second hidden layer?
# - How does the training algorithm affect the quality of the model?
# - Project the embeddings of the labels onto 2 dimensions and visualise (each row of the projection matrix V corresponds a label embedding). Do you see anything interesting?

# %%
W = tf.Variable(tf.truncated_normal(shape=[100, 256]))
b = tf.Variable(tf.constant(0.0, shape=[256]))

W2 = tf.Variable(tf.truncated_normal(shape=[256, 128]))
b2 = tf.Variable(tf.constant(0.0, shape=[128]))

V = tf.Variable(tf.truncated_normal(shape=[128, 8]))
c = tf.Variable(tf.constant(0.0, shape=[8]))

dropout_rate = tf.placeholder(tf.float32)

h = tf.nn.relu(tf.matmul(x, W) + b)
h2 = tf.nn.relu(tf.matmul(h, W2) + b2)
h2_drop = tf.nn.dropout(h2, keep_prob=dropout_rate)
u = tf.matmul(h2_drop, V) + c
p = tf.nn.softmax(u)
pred = tf.argmax(p, 1)

loss = tf.reduce_mean(tf.reduce_sum(-tf.cast(y, tf.float32)*tf.log(p), 1))
accuracy = tf.reduce_mean(tf.cast(tf.equal(pred, tf.argmax(y, 1)), tf.float32))
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)
saver = tf.train.Saver()

# %%
init = tf.global_variables_initializer()
sess.run(init)

# %%
for i in range(epoch):
    xloss = 0
    acc = 0.0
    
    for j in range(total_batch):
        # need to incoporate y in the batches and expand to 8 classes 
        index, x_, y_ = next_batch(train_doc_embed_with_class, index, batch_size)
        _, xloss = sess.run([optimizer, loss], feed_dict={x: x_, y: y_, dropout_rate: 0.5})
        
        if j % 30 == 0:
            print("epoch %d, run %d, loss %g" % (i, j, xloss))
            
    if i % 100 == 0:
        acc = sess.run(accuracy, feed_dict={x:test_doc_embed_with_class[0], y:test_doc_embed_with_class[1], dropout_rate: 1.0})
        print("epoch %d, Test acc: %g" % (i, acc * 100), end="")
        print("%")
        
save_path = saver.save(sess, "/tmp/model"+str(time.time())+".ckpt")
print("Model saved in file: %s" % save_path)
# Out:
# epoch 0, Validation acc: 30.4%
# epoch 100, Validation acc: 39.2%
# epoch 200, Validation acc: 40.4%
# epoch 300, Validation acc: 42%
# epoch 400, Validation acc: 44%
# epoch 500, Validation acc: 44.8%
# epoch 600, Validation acc: 45.2%
# epoch 700, Validation acc: 45.2%
# epoch 800, Validation acc: 44.8%
# epoch 900, Validation acc: 45.2%
# epoch 1000, Validation acc: 44.8%
# epoch 1100, Validation acc: 44.8%
# epoch 1200, Validation acc: 44.8%
# epoch 1300, Validation acc: 42%
# epoch 1400, Validation acc: 43.2%
# epoch 1500, Validation acc: 44%
# epoch 1600, Validation acc: 44%
# epoch 1700, Validation acc: 42%
# epoch 1800, Validation acc: 42.4%
# epoch 1900, Validation acc: 39.2%
# epoch 2000, Validation acc: 43.2%
# epoch 2100, Validation acc: 42.4%
# epoch 2200, Validation acc: 42.8%
# epoch 2300, Validation acc: 42.4%
# epoch 2400, Validation acc: 44.4%
# epoch 2500, Validation acc: 43.2%
# epoch 2600, Validation acc: 43.2%
# epoch 2700, Validation acc: 44%
# epoch 2800, Validation acc: 43.6%
# epoch 2900, Validation acc: 42%
