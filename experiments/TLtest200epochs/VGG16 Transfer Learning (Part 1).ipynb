# %% [markdown]
# # CNN Transfer Learning with VGG16 (Part 1)

# %%
import numpy as np
import h5py
import tensorflow as tf
import matplotlib.pyplot as plt 
# %matplotlib inline

import keras
from keras.applications.vgg16 import preprocess_input 
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image

from keras.layers import Input, Flatten, Dense
from keras.models import Model

# %%
from keras import applications

input_img = tf.placeholder(tf.float32, shape=(None, 224, 224, 3))
print(input_img)

# model = VGG16(weights='imagenet', input_tensor=input_img)
model_vgg16 = VGG16(weights='imagenet', include_top=False)
# Out:
# Tensor("Placeholder_135:0", shape=(?, 224, 224, 3), dtype=float32)

# %%
model_vgg16.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.datasets import cifar10

num_classes = 10
batch_size = 100
epochs = 100

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')


# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
image_size = 32
channel = 3
input_layer = Input(shape=(image_size, image_size, channel), name='image_input')

# %%
# take the output from chopped-off vgg16 model 
output_model_vgg16 = model_vgg16(input_layer)

x = Flatten(name='flatten')(output_model_vgg16)
x = Dense(1024, activation='relu', name='fc1')(x)
x = Dense(1024, activation='relu', name='fc2')(x)
x = Dense(10, activation='softmax', name='predictions')(x)

new_model = Model(input=input_layer, output=x)
new_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# image_input (InputLayer)     (None, 32, 32, 3)         0
# _________________________________________________________________
# vgg16 (Model)                multiple                  14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 1024)              525312
# _________________________________________________________________
# fc2 (Dense)                  (None, 1024)              1049600
# _________________________________________________________________
# predictions (Dense)          (None, 10)                10250
# =================================================================
# Total params: 16,299,850
# Trainable params: 16,299,850
# Non-trainable params: 0
# _________________________________________________________________
# /home/justin-y/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:9: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("im..., outputs=Tensor("pr...)`

# %%
layer_count = 0 
for layer in new_model.layers:
    layer_count = layer_count + 1
    print(layer)
# Out:
# <keras.engine.topology.InputLayer object at 0x7fcc927a5f28>
# <keras.engine.training.Model object at 0x7fcc94434a90>
# <keras.layers.core.Flatten object at 0x7fcc927b8748>
# <keras.layers.core.Dense object at 0x7fcc927b8630>
# <keras.layers.core.Dense object at 0x7fcc927bbf28>
# <keras.layers.core.Dense object at 0x7fcc927289b0>

# %%
# fix pretrained weights in vgg16 for training 
for i in range(layer_count-3):
    new_model.layers[i].trainable = False

# %% [markdown]
# ## Train the new model

# %%
opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)

new_model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
new_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, 
             validation_data=(x_test, y_test), shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 1250s - loss: 1.4995 - acc: 0.4820 - val_loss: 1.3265 - val_acc: 0.5376
# Epoch 2/100
# 50000/50000 [==============================] - 1407s - loss: 1.2551 - acc: 0.5611 - val_loss: 1.2618 - val_acc: 0.5574
# Epoch 3/100
# 50000/50000 [==============================] - 1433s - loss: 1.1820 - acc: 0.5879 - val_loss: 1.2133 - val_acc: 0.5752
# Epoch 4/100
# 50000/50000 [==============================] - 1462s - loss: 1.0933 - acc: 0.6188 - val_loss: 1.1500 - val_acc: 0.6040
# Epoch 6/100
# 50000/50000 [==============================] - 1464s - loss: 1.0599 - acc: 0.6314 - val_loss: 1.1226 - val_acc: 0.6034
# Epoch 7/100
# 50000/50000 [==============================] - 1837s - loss: 0.9066 - acc: 0.6850 - val_loss: 1.0826 - val_acc: 0.6214
# Epoch 13/100
# 50000/50000 [==============================] - 1827s - loss: 0.8402 - acc: 0.7073 - val_loss: 1.0693 - val_acc: 0.6319
# Epoch 16/100
# 50000/50000 [==============================] - 1803s - loss: 0.8184 - acc: 0.7180 - val_loss: 1.0720 - val_acc: 0.6326
# Epoch 17/100
# 50000/50000 [==============================] - 1825s - loss: 0.7980 - acc: 0.7235 - val_loss: 1.0845 - val_acc: 0.6290
# Epoch 18/100
# 50000/50000 [==============================] - 1469s - loss: 0.6012 - acc: 0.7957 - val_loss: 1.1870 - val_acc: 0.6226
# Epoch 28/100
# 50000/50000 [==============================] - 1466s - loss: 0.5822 - acc: 0.8042 - val_loss: 1.1644 - val_acc: 0.6267
# Epoch 29/100
# 50000/50000 [==============================] - 1448s - loss: 0.5653 - acc: 0.8107 - val_loss: 1.1496 - val_acc: 0.6328
# Epoch 30/100
# 50000/50000 [==============================] - 1485s - loss: 0.5473 - acc: 0.8170 - val_loss: 1.1516 - val_acc: 0.6295
# Epoch 31/100
# 50000/50000 [==============================] - 1470s - loss: 0.5297 - acc: 0.8238 - val_loss: 1.1896 - val_acc: 0.6230
# Epoch 32/100
# 50000/50000 [==============================] - 1831s - loss: 0.4950 - acc: 0.8356 - val_loss: 1.1906 - val_acc: 0.6364
# Epoch 34/100
#  8300/50000 [===>..........................] - ETA: 1221s - loss: 0.4740 - acc: 0.8467

# %%
new_model.save('new_model.h5')

new_model.save_weights('new_model_weights.h5')

print("new model saved")
