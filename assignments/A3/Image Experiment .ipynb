# %%
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg 
import numpy as np 
import pandas as pd

# %matplotlib inline

# %%
img = mpimg.imread('test.jpg')
imgshow = plt.imshow(img)

# %%
testimg = np.random.normal(size=[32, 32, 3])
plt.imshow(testimg)

# %%
blank = np.zeros([36, 36, 3])
blank[2:34, 2:34, :] = testimg
plt.imshow(blank)

# %%
s = blank.shape
plt.imshow(blank[2:s[0]-2, 2:s[1]-2, :].copy())

# %%
k = np.ones([32,32,3])
plt.imshow(k)
