# %%
from __future__ import print_function 
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
label_num = 8

# %%
f = np.load('corpus_all_9999.npz')

# %%
f.files
# Out:
# ['test_doc', 'valid_doc', 'train_doc']

# %%
train_doc = f['train_doc']
# Out:
# Exception ignored in: 'zmq.backend.cython.message.Frame.__dealloc__'
# Traceback (most recent call last):
#   File "zmq/backend/cython/checkrc.pxd", line 12, in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/message.c:4294)
# KeyboardInterrupt

# %%
print(type(train_doc))
# Out:
# <class 'numpy.ndarray'>

# %%
print(train_doc[0][1])
# Out:
# 0

# %%
valid_doc = f['valid_doc']

# %%
test_doc = f['test_doc']

# %%
min_count = 100
max_count = 0

for doc in train_doc:
    for sent in doc[0]:
        if len(sent) < min_count:
            min_count = len(sent)
        if len(sent) > max_count:
            max_count = len(sent)
            
print(min_count)
print(max_count)
# Out:
# 1
# 290

# %%
def convert2words(doc):
    return [word for sent in doc for word in sent]

# %%
train_doc_words = np.asarray([(convert2words(doc[0]), doc[1]) for doc in train_doc])

# %%
print(train_doc_words[0][0])
# Out:
# ['here', 'are', 'two', 'reasons', 'companies', 'fail', 'they', 'only', 'do', 'more', 'of', 'the', 'same', 'or', 'they', 'only', 'do', 'what', 's', 'new', 'to', 'me', 'the', 'real', 'real', 'solution', 'to', 'quality', 'growth', 'is', 'figuring', 'out', 'the', 'balance', 'between', 'two', 'activities', 'exploration', 'and', 'exploitation', 'both', 'are', 'necessary', 'but', 'it', 'can', 'be', 'too', 'much', 'of', 'a', 'good', 'thing', 'consider', 'UnknownTK', 'i', 'm', 'actually', 'old', 'enough', 'to', 'remember', 'them', 'UnknownTK', 'was', 'a', 'fantastic', 'company', 'they', 'were', 'born', 'deep', 'in', 'the', 'swedish', 'forest', 'and', 'they', 'made', 'the', 'best', 'mechanical', 'UnknownTK', 'in', 'the', 'world', 'everybody', 'used', 'them', 'and', 'what', 'did', 'UnknownTK', 'do', 'when', 'the', 'electronic', 'UnknownTK', 'came', 'along', 'they', 'continued', 'doing', 'exactly', 'the', 'same', 'in', 'six', 'months', 'they', 'went', 'from', 'maximum', 'revenue', 'and', 'they', 'were', 'gone', 'gone', 'to', 'me', 'the', 'irony', 'about', 'the', 'UnknownTK', 'story', 'is', 'hearing', 'about', 'the', 'UnknownTK', 'engineers', 'who', 'had', 'bought', 'cheap', 'small', 'electronic', 'UnknownTK', 'in', 'japan', 'that', 'they', 'used', 'to', 'double', 'check', 'their', 'UnknownTK', 'UnknownTK', 'did', 'too', 'much', 'exploitation', 'but', 'exploration', 'can', 'go', 'wild', 'too', 'a', 'few', 'years', 'back', 'i', 'worked', 'closely', 'alongside', 'a', 'european', 'biotech', 'company', 'let', 's', 'call', 'them', 'UnknownTK', 'the', 'company', 'was', 'brilliant', 'they', 'had', 'applications', 'that', 'promised', 'to', 'diagnose', 'even', 'cure', 'certain', 'forms', 'of', 'blood', 'cancer', 'every', 'day', 'was', 'about', 'creating', 'something', 'new', 'they', 'were', 'extremely', 'innovative', 'and', 'the', 'mantra', 'was', 'when', 'we', 'only', 'get', 'it', 'right', 'or', 'even', 'we', 'want', 'it', 'perfect', 'the', 'sad', 'thing', 'is', 'before', 'they', 'became', 'perfect', 'even', 'good', 'enough', 'they', 'became', 'obsolete', 'UnknownTK', 'did', 'too', 'much', 'exploration', 'i', 'first', 'heard', 'about', 'exploration', 'and', 'exploitation', 'about', '15', 'years', 'ago', 'when', 'i', 'worked', 'as', 'a', 'visiting', 'scholar', 'at', 'stanford', 'university', 'the', 'founder', 'of', 'the', 'idea', 'is', 'jim', 'march', 'and', 'to', 'me', 'the', 'power', 'of', 'the', 'idea', 'is', 'its', 'UnknownTK', 'exploration', 'exploration', 'is', 'about', 'coming', 'up', 'with', 'what', 's', 'new', 'it', 's', 'about', 'search', 'it', 's', 'about', 'discovery', 'it', 's', 'about', 'new', 'products', 'it', 's', 'about', 'new', 'innovations', 'it', 's', 'about', 'changing', 'our', 'frontiers', 'our', 'heroes', 'are', 'people', 'who', 'have', 'done', 'exploration', 'UnknownTK', 'UnknownTK', 'picasso', 'neil', 'armstrong', 'sir', 'UnknownTK', 'UnknownTK', 'etc', 'i', 'come', 'from', 'norway', 'all', 'our', 'heroes', 'are', 'explorers', 'and', 'they', 'deserve', 'to', 'be', 'we', 'all', 'know', 'that', 'exploration', 'is', 'risky', 'we', 'don', 't', 'know', 'the', 'answers', 'we', 'don', 't', 'know', 'if', 'we', 're', 'going', 'to', 'find', 'them', 'and', 'we', 'know', 'that', 'the', 'risks', 'are', 'high', 'exploitation', 'is', 'the', 'opposite', 'exploitation', 'is', 'taking', 'the', 'knowledge', 'we', 'have', 'and', 'making', 'good', 'better', 'exploitation', 'is', 'about', 'making', 'our', 'trains', 'run', 'on', 'time', 'it', 's', 'about', 'making', 'good', 'products', 'faster', 'and', 'cheaper', 'exploitation', 'is', 'not', 'risky', 'in', 'the', 'short', 'term', 'but', 'if', 'we', 'only', 'exploit', 'it', 's', 'very', 'risky', 'in', 'the', 'long', 'term', 'and', 'i', 'think', 'we', 'all', 'have', 'memories', 'of', 'the', 'famous', 'pop', 'groups', 'who', 'keep', 'singing', 'the', 'same', 'songs', 'again', 'and', 'again', 'until', 'they', 'become', 'obsolete', 'or', 'even', 'pathetic', 'that', 's', 'the', 'risk', 'of', 'exploitat ...

# %%
print(train_doc[0])
# Out:
# [ [['here', 'are', 'two', 'reasons', 'companies', 'fail', 'they', 'only', 'do', 'more', 'of', 'the', 'same', 'or', 'they', 'only', 'do', 'what', 's', 'new'], ['to', 'me', 'the', 'real', 'real', 'solution', 'to', 'quality', 'growth', 'is', 'figuring', 'out', 'the', 'balance', 'between', 'two', 'activities', 'exploration', 'and', 'exploitation'], ['both', 'are', 'necessary', 'but', 'it', 'can', 'be', 'too', 'much', 'of', 'a', 'good', 'thing'], ['consider', 'UnknownTK'], ['i', 'm', 'actually', 'old', 'enough', 'to', 'remember', 'them'], ['UnknownTK', 'was', 'a', 'fantastic', 'company'], ['they', 'were', 'born', 'deep', 'in', 'the', 'swedish', 'forest', 'and', 'they', 'made', 'the', 'best', 'mechanical', 'UnknownTK', 'in', 'the', 'world'], ['everybody', 'used', 'them'], ['and', 'what', 'did', 'UnknownTK', 'do', 'when', 'the', 'electronic', 'UnknownTK', 'came', 'along', 'they', 'continued', 'doing', 'exactly', 'the', 'same'], ['in', 'six', 'months', 'they', 'went', 'from', 'maximum', 'revenue'], ['and', 'they', 'were', 'gone'], ['gone'], ['to', 'me', 'the', 'irony', 'about', 'the', 'UnknownTK', 'story', 'is', 'hearing', 'about', 'the', 'UnknownTK', 'engineers', 'who', 'had', 'bought', 'cheap', 'small', 'electronic', 'UnknownTK', 'in', 'japan', 'that', 'they', 'used', 'to', 'double', 'check', 'their', 'UnknownTK'], ['UnknownTK', 'did', 'too', 'much', 'exploitation'], ['but', 'exploration', 'can', 'go', 'wild', 'too'], ['a', 'few', 'years', 'back', 'i', 'worked', 'closely', 'alongside', 'a', 'european', 'biotech', 'company'], ['let', 's', 'call', 'them', 'UnknownTK'], ['the', 'company', 'was', 'brilliant'], ['they', 'had', 'applications', 'that', 'promised', 'to', 'diagnose', 'even', 'cure', 'certain', 'forms', 'of', 'blood', 'cancer'], ['every', 'day', 'was', 'about', 'creating', 'something', 'new'], ['they', 'were', 'extremely', 'innovative', 'and', 'the', 'mantra', 'was', 'when', 'we', 'only', 'get', 'it', 'right', 'or', 'even', 'we', 'want', 'it', 'perfect'], ['the', 'sad', 'thing', 'is', 'before', 'they', 'became', 'perfect', 'even', 'good', 'enough', 'they', 'became', 'obsolete'], ['UnknownTK', 'did', 'too', 'much', 'exploration'], ['i', 'first', 'heard', 'about', 'exploration', 'and', 'exploitation', 'about', '15', 'years', 'ago', 'when', 'i', 'worked', 'as', 'a', 'visiting', 'scholar', 'at', 'stanford', 'university'], ['the', 'founder', 'of', 'the', 'idea', 'is', 'jim', 'march'], ['and', 'to', 'me', 'the', 'power', 'of', 'the', 'idea', 'is', 'its', 'UnknownTK'], ['exploration'], ['exploration', 'is', 'about', 'coming', 'up', 'with', 'what', 's', 'new'], ['it', 's', 'about', 'search', 'it', 's', 'about', 'discovery', 'it', 's', 'about', 'new', 'products', 'it', 's', 'about', 'new', 'innovations'], ['it', 's', 'about', 'changing', 'our', 'frontiers'], ['our', 'heroes', 'are', 'people', 'who', 'have', 'done', 'exploration', 'UnknownTK', 'UnknownTK', 'picasso', 'neil', 'armstrong', 'sir', 'UnknownTK', 'UnknownTK', 'etc'], ['i', 'come', 'from', 'norway', 'all', 'our', 'heroes', 'are', 'explorers', 'and', 'they', 'deserve', 'to', 'be'], ['we', 'all', 'know', 'that', 'exploration', 'is', 'risky'], ['we', 'don', 't', 'know', 'the', 'answers', 'we', 'don', 't', 'know', 'if', 'we', 're', 'going', 'to', 'find', 'them', 'and', 'we', 'know', 'that', 'the', 'risks', 'are', 'high'], ['exploitation', 'is', 'the', 'opposite'], ['exploitation', 'is', 'taking', 'the', 'knowledge', 'we', 'have', 'and', 'making', 'good', 'better'], ['exploitation', 'is', 'about', 'making', 'our', 'trains', 'run', 'on', 'time'], ['it', 's', 'about', 'making', 'good', 'products', 'faster', 'and', 'cheaper'], ['exploitation', 'is', 'not', 'risky', 'in', 'the', 'short', 'term'], ['but', 'if', 'we', 'only', 'exploit', 'it', 's', 'very', 'risky', 'in', 'the', 'long', 'term'], ['and', 'i', 'think', 'we', 'all', 'have', 'memories', 'of', 'the', 'famous', 'pop', 'groups', 'who', 'keep', 'singing', 'the', 'same', 'songs', 'again', 'and', 'again', 'until', 'they', 'become', ...
#  0]

# %% [markdown]
# ## Build the vocabulary

# %%
from collections import Counter

# %%
counts_new = []
            
words_count_list = Counter([word for doc in train_doc for sent in doc[0] for word in sent]).most_common(10000)

# %%
print(len(words_count_list))
print(words_count_list)
# Out:
# 10000
# [('the', 148314), ('UnknownTK', 114199), ('and', 106841), ('to', 90699), ('of', 81748), ('a', 75296), ('that', 67989), ('i', 58165), ('in', 56239), ('it', 51467), ('we', 49525), ('you', 48659), ('is', 44322), ('s', 39674), ('this', 34350), ('so', 26684), ('they', 24061), ('was', 22167), ('for', 21997), ('are', 20578), ('have', 19551), ('but', 19548), ('what', 18804), ('on', 18404), ('with', 18036), ('can', 16881), ('t', 15902), ('about', 14829), ('there', 14424), ('be', 14213), ('as', 13995), ('at', 13779), ('my', 13530), ('not', 13494), ('all', 13302), ('do', 12585), ('one', 12363), ('people', 12243), ('re', 11888), ('like', 11718), ('if', 11281), ('from', 11277), ('our', 10924), ('now', 10475), ('or', 10109), ('an', 10083), ('these', 9982), ('he', 9883), ('just', 9878), ('when', 9838), ('because', 9190), ('me', 9153), ('by', 8685), ('very', 8564), ('how', 8482), ('out', 8456), ('them', 8455), ('more', 8139), ('up', 7895), ('had', 7878), ('their', 7729), ('who', 7710), ('were', 7694), ('going', 7600), ('your', 7413), ('see', 7304), ('know', 7270), ('think', 7140), ('would', 7023), ('which', 6918), ('really', 6717), ('us', 6637), ('here', 6566), ('ve', 6494), ('get', 6462), ('then', 6444), ('time', 6383), ('world', 6319), ('m', 6275), ('some', 6071), ('actually', 5937), ('has', 5911), ('don', 5700), ('where', 5624), ('into', 5613), ('will', 5453), ('way', 5420), ('years', 5358), ('other', 5253), ('could', 5217), ('well', 5149), ('no', 5138), ('been', 5006), ('things', 4999), ('want', 4912), ('go', 4895), ('she', 4810), ('make', 4772), ('those', 4678), ('right', 4549), ('first', 4504), ('two', 4478), ('something', 4451), ('than', 4419), ('said', 4363), ('also', 4292), ('much', 4233), ('new', 4046), ('look', 3992), ('even', 3990), ('most', 3935), ('over', 3844), ('back', 3798), ('his', 3764), ('work', 3761), ('only', 3753), ('need', 3746), ('many', 3700), ('thing', 3665), ('little', 3652), ('take', 3637), ('life', 3628), ('got', 3597), ('say', 3546), ('did', 3285), ('every', 3247), ('her', 3228), ('why', 3227), ('around', 3186), ('different', 3164), ('lot', 3117), ('let', 3103), ('good', 3079), ('through', 2993), ('same', 2964), ('day', 2897), ('kind', 2817), ('use', 2806), ('being', 2800), ('down', 2786), ('year', 2747), ('come', 2730), ('three', 2695), ('ll', 2655), ('d', 2624), ('today', 2588), ('thank', 2514), ('doing', 2501), ('called', 2499), ('percent', 2492), ('any', 2433), ('after', 2416), ('tell', 2365), ('put', 2361), ('made', 2289), ('find', 2271), ('human', 2270), ('great', 2245), ('fact', 2242), ('change', 2230), ('own', 2166), ('didn', 2137), ('started', 2123), ('might', 2094), ('before', 2088), ('its', 2082), ('talk', 2061), ('better', 2040), ('another', 2004), ('never', 2001), ('idea', 1990), ('big', 1975), ('should', 1975), ('give', 1974), ('last', 1965), ('together', 1961), ('able', 1960), ('women', 1955), ('problem', 1951), ('still', 1948), ('important', 1920), ('system', 1901), ('thought', 1885), ('went', 1877), ('again', 1869), ('story', 1855), ('part', 1852), ('each', 1850), ('next', 1848), ('course', 1838), ('brain', 1838), ('000', 1833), ('start', 1818), ('data', 1803), ('him', 1794), ('off', 1777), ('does', 1772), ('few', 1770), ('used', 1757), ('between', 1739), ('ago', 1733), ('long', 1723), ('came', 1710), ('show', 1693), ('water', 1687), ('example', 1668), ('place', 1663), ('old', 1640), ('found', 1639), ('maybe', 1624), ('too', 1623), ('technology', 1616), ('question', 1607), ('bit', 1603), ('school', 1597), ('doesn', 1549), ('looking', 1526), ('end', 1520), ('ever', 1519), ('children', 1496), ('wanted', 1495), ('10', 1492), ('love', 1492), ('live', 1492), ('understand', 1487), ('done', 1474), ('help', 1474), ('real', 1467), ('mean', 1459), ('call', 1445), ('four', 1443), ('point', 1438), ('may', 1426), ('information', 1425), ('country', 1417), ('trying', 1408), ('feel', 1408), ('always', 1403), ('believe', 1400), ('away', 1395), ('person', 1394), ('using', 1380), ('working', 1375), ('home', 1369), ...

# %%
l = [1,2,3,4,4]
for i in enumerate(l, 1):
    print(i)
# Out:
# (1, 1)
# (2, 2)
# (3, 3)
# (4, 4)
# (5, 4)

# %%
word2index = {item[0]: index for index, item in enumerate(words_count_list, 1)}
index2word = {index: item[0] for index, item in enumerate(words_count_list, 1)}

# %%
print(word2index['and'])
print(index2word[3])
# Out:
# 3
# and

# %%
def doc2index(doc, word2index):
    return [word2index[word] for word in doc]

# %%
train_wordasindex = np.asarray([doc2index(doc[0], word2index) for doc in train_doc_words])

# %%
print(train_wordasindex.shape)
print(train_wordasindex[0][0])
print(train_wordasindex[0])
# Out:
# (1579,)
# 73
# [73, 20, 102, 832, 514, 1857, 17, 116, 36, 58, 5, 1, 135, 45, 17, 116, 36, 23, 14, 108, 4, 52, 1, 228, 228, 759, 4, 819, 604, 13, 3532, 56, 1, 1858, 200, 102, 2095, 2345, 3, 5217, 353, 20, 1584, 22, 10, 26, 30, 211, 107, 5, 6, 133, 119, 1016, 2, 8, 79, 81, 208, 288, 4, 340, 57, 2, 18, 6, 1227, 499, 17, 63, 608, 678, 9, 1, 7203, 1202, 3, 17, 155, 1, 262, 2229, 2, 9, 1, 78, 449, 199, 57, 3, 23, 125, 2, 36, 50, 1, 2644, 2, 203, 545, 17, 3071, 148, 452, 1, 135, 9, 362, 376, 17, 184, 42, 5539, 3717, 3, 17, 63, 642, 642, 4, 52, 1, 4771, 28, 1, 2, 186, 13, 1442, 28, 1, 2, 1836, 62, 60, 1520, 2268, 259, 2644, 2, 9, 1642, 7, 17, 199, 4, 1755, 1508, 61, 2, 2, 125, 211, 107, 5217, 22, 2345, 26, 96, 1684, 211, 6, 198, 88, 113, 8, 497, 2730, 4482, 6, 1474, 7859, 499, 132, 14, 230, 57, 2, 1, 499, 18, 1785, 17, 60, 2281, 7, 3718, 4, 6178, 110, 1810, 618, 1102, 5, 652, 370, 126, 136, 18, 28, 738, 103, 108, 17, 63, 927, 2360, 3, 1, 6966, 18, 50, 11, 116, 75, 10, 100, 45, 110, 11, 95, 10, 885, 1, 1786, 119, 13, 165, 17, 433, 885, 110, 133, 288, 17, 433, 4958, 2, 125, 211, 107, 2345, 8, 101, 418, 28, 2345, 3, 5217, 28, 533, 88, 201, 50, 8, 497, 31, 6, 4406, 6325, 32, 3490, 776
255, 103, 108, 22, 1, 135, 359, 19, 7, 76, 11, 39, 9, 1, 6480, 1708, 5, 81, 317, 59, 25, 465, 22, 139, 3041, 2, 18, 6, 133, 206, 6, 1172, 206, 13, 5, 190, 2, 22, 11, 83, 27, 116, 66, 15, 9, 514, 11, 66, 15, 9, 1, 354, 1732, 31, 91, 11, 35, 67, 7, 151, 137, 5, 1039, 2996, 5, 437, 378, 295, 306, 110, 2494, 556, 222, 533, 210, 325, 88, 4, 115, 22, 180, 11, 160, 107, 58, 348, 11, 71, 83, 27, 174, 57, 1, 820, 169, 5424, 13, 1, 879, 5424, 2, 1825, 85, 1, 879, 5424, 17, 743, 1443, 1, 268, 9, 61, 581, 22, 17, 508, 27, 66, 10, 17, 63, 550, 16, 133, 32, 275, 23, 17, 977, 148, 7, 17, 658, 27, 160, 11, 20, 40, 7, 211, 50, 11, 67, 103, 91, 10, 14, 530, 4, 160, 1461, 3072, 82, 105, 879, 13, 6, 2, 1017, 10, 2, 72, 85, 248, ...

# %%
# API for corpuse format conversion 

def convert2words(doc):
    return [word for sent in doc for word in sent]

def doc2index(doc, word2index):
    return [[word2index[word]] for word in doc]

def convert_corpus(corpus, word2index):
    corpus_words = [(convert2words(doc[0]), doc[1]) for doc in corpus]
    return np.asarray([doc2index(doc[0], word2index) for doc in corpus_words])

# %%
train_wordasindex = convert_corpus(train_doc, word2index)
valid_wordasindex = convert_corpus(valid_doc, word2index)
test_wordasindex = convert_corpus(test_doc, word2index)

# %%
print(train_wordasindex.shape)
print(len(train_wordasindex[0]))
print(train_wordasindex[0][0])
# Out:
# (1579,)
# 1364
# [73]

# %% [markdown]
# ## Embed words

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec.load("word2vec_model")

# %%
print(len(model.wv.vocab))
# Out:
# 10000

# %%
print(word2index['computer'])
print(index2word[394])
# print(model.wv[index2word[394]])
print(model.wv[index2word[394]].shape)
# model.most_similar(index2word[394])
# Out:
# 394
# computer
# (100,)

# %%
def embed_from_index(model, idx):
    if idx != 0:
        return model.wv[index2word[idx]]
    else:
        return np.zeros(shape=model.wv[index2word[1]].shape)

def embed_corpus(corpus, word2index, model):
    temp = list(corpus)
    return np.asarray([[embed_from_index(model, idx) for sent in doc for idx in sent] for doc in temp])

# %%
# train_wordasindex_embed = embed_corpus(np.asarray(train_doc), word2index, model)
# #

# %%
# print(train_wordasindex_embed.shape)
# print(len(train_wordasindex_embed[0]))
# print(train_wordasindex_embed[0][0])

# %%
# print(train_wordasindex_embed[0][0].shape)

# %%
# train_wordasindex_embed = embed_corpus(train_doc, word2index, model)
# valid_wordasindex_embed = embed_corpus(valid_doc, word2index, model)
# test_wordasindex_embed = embed_corpus(test_doc, word2index, model)

# %% [markdown]
#    ## Convert labels

# %%
def encode_label(label, size):
    l = [0]*size
    l[label] = 1
    return l

def encode_class(corpus, size):
    return np.asarray([encode_label(doc[1], size) for doc in corpus])

# %%
train_label = encode_class(train_doc, 8)
valid_label = encode_class(valid_doc, 8)
test_label = encode_class(test_doc, 8)

# %%
# %%
k = [1, 2, 3]
pad_with_zeros(k,5)
# Out:
# [1, 2, 3, [0], [0]]

# %%
def corpus_pad_with_zeros(corpus, maxlen):
    return np.asarray([pad_with_zeros(sent, maxlen) for sent in corpus])

# %%
train_corpus = corpus_pad_with_zeros(train_wordasindex, maxlen)
valid_corpus = corpus_pad_with_zeros(valid_wordasindex, maxlen)
test_corpus = corpus_pad_with_zeros(test_wordasindex, maxlen)

# %%
print(train_corpus.shape)
print(train_label.shape)
print(train_corpus[0].shape)
print(train_corpus[3].shape)
print(train_corpus[45].shape)
print(train_corpus[90].shape)
print(train_corpus[0])
# Out:
# (1579, 6700, 1)
# (1579, 8)
# (6700, 1)
# (6700, 1)
# (6700, 1)
# (6700, 1)
# [[ 73]
#  [ 20]
#  [102]
#  ...,
#  [  0]
#  [  0]
#  [  0]]

# %%
train_corpus_embed = embed_corpus(train_corpus, word2index, model)
valid_corpus_embed = embed_corpus(valid_corpus, word2index, model)
test_corpus_embed = embed_corpus(test_corpus, word2index, model)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-206-cbc90e8d5700> in <module>()
# ----> 1 train_corpus_embed = embed_corpus(train_corpus, word2index, model)
#       2 valid_corpus_embed = embed_corpus(valid_corpus, word2index, model)
#       3 test_corpus_embed = embed_corpus(test_corpus, word2index, model)
#
# <ipython-input-185-d5e9453e5f63> in embed_corpus(corpus, word2index, model)
#       7 def embed_corpus(corpus, word2index, model):
#       8     temp = list(corpus)
# ----> 9     return np.asarray([[embed_from_index(model, idx) for sent in doc for idx in sent] for doc in temp])
#
# <ipython-input-185-d5e9453e5f63> in <listcomp>(.0)
#       7 def embed_corpus(corpus, word2index, model):
#       8     temp = list(corpus)
# ----> 9     return np.asarray([[embed_from_index(model, idx) for sent in doc for idx in sent] for doc in temp])
#
# <ipython-input-185-d5e9453e5f63> in <listcomp>(.0)
#       7 def embed_corpus(corpus, word2index, model):
#       8     temp = list(corpus)
# ----> 9     return np.asarray([[embed_from_index(model, idx) for sent in doc for idx in sent] for doc in temp])
#
# <ipython-input-185-d5e9453e5f63> in embed_from_index(model, idx)
#       3         return model.wv[index2word[idx]]
#       4     else:
# ----> 5         return np.zeros(shape=model.wv[index2word[1]].shape)
#       6
#       7 def embed_corpus(corpus, word2index, model):
#
# /home/justin-y/anaconda3/lib/python3.6/site-packages/gensim-1.0.1-py3.6-linux-x86_64.egg/gensim/models/keyedvectors.py in __getitem__(self, words)
#     572         if isinstance(words, string_types):
#     573             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 574             return self.word_vec(words)
#     575
#     576         return vstack([self.word_vec(word) for word in words])
#
# /home/justin-y/anaconda3/lib/python3.6/site-packages/gensim-1.0.1-py3.6-linux-x86_64.egg/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     252         return result
#     253
# --> 254     def word_vec(self, word, use_norm=False):
#     255         """
#     256         Accept a single word as input.
#
# KeyboardInterrupt:

# %%
print(train_corpus_embed.shape)
print(train_label.shape)
print(train_corpus_embed[0].shape)
print(train_corpus_embed[3].shape)
print(train_corpus_embed[45].shape)
print(train_corpus_embed[90].shape)
print(train_corpus_embed[0])

# %%
print(valid_corpus.shape)
print(valid_label.shape)

# %%
def next_batch(data, index, size):
    """ return next batch in format: index, x batch, y batch
    """
    if index + size <= data[0].shape[0]:
        return index+size, data[0][index:index+size], data[1][index:index+size]
    else:
        return index+size-data[0].shape[0], np.concatenate((data[0][index:],data[0][:index+size-data[0].shape[0]]), 0), \
    np.concatenate((data[1][index:],data[1][:index+size-data[1].shape[0]]), 0)

# %%
def length(sequence):
    used = tf.sign(tf.reduce_max(tf.abs(sequence), reduction_indices=2))
    length = tf.reduce_sum(used, reduction_indices=1)
    length = tf.cast(length, tf.int32)
    return length

# %%
# tensorflow wants a data format of [Batch Size, Sequence Length, Input Dimension].
x = tf.placeholder(tf.float32, [None, maxlen, input_dims])
y = tf.placeholder(tf.float32, [None, 8])

# %%
with tf.variable_scope('cellsdef', reuse=True):
    cell_fw = tf.contrib.rnn.GRUCell(num_hidden, state_is_tuple=True)
    cell_bw = tf.contrib.rnn.GRUCell(num_hidden, state_is_tuple=True)

# %%
with tf.variable_scope('lstmrnn'):
    val, state = tf.nn.dynamic_rnn(cell_fw, x, dtype=tf.float32, sequence_length=length(x))    # val are the h_ts

# %%
print(val.shape)
print(len(state))
print(state[0].shape)
print(state[1].shape)

# %%
print(length(x))

# %%
W = tf.Variable(tf.truncated_normal(shape=[50, 32]))
b = tf.Variable(tf.constant(0.0, shape=[32]))

V = tf.Variable(tf.truncated_normal(shape=[32, 8]))
c = tf.Variable(tf.constant(0.0, shape=[8]))

# dropout_rate = tf.placeholder(tf.float32)

h = tf.nn.relu(tf.matmul(tf.reduce_mean(val, axis=1), W) + b)
# h = tf.nn.relu(tf.matmul(state[1], W) + b)
u = tf.matmul(h, V) + c
p = tf.nn.softmax(u)
pred = tf.argmax(p, 1)
loss = tf.reduce_mean(tf.reduce_sum(-tf.cast(y, tf.float32)*tf.log(p), 1))

# %%
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)

# %%
accuracy = tf.reduce_mean(tf.cast(tf.equal(pred, tf.argmax(y, 1)), tf.float32))

# %%
sess = tf.InteractiveSession()

# %%
init = tf.global_variables_initializer()
sess.run(init)

# %%
for i in range(epochs+1):
    xloss = 0
    acc = 0.0
    
    for j in range(total_batch):
        # need to incoporate y in the batches and expand to 8 classes 
        index, x_, y_ = next_batch((train_corpus_embed, train_label), index, batch_size)
        _, xloss = sess.run([optimizer, loss], feed_dict={x: x_, y: y_})
        
        if j % 10 == 0:
            print("epoch %d, run %d, loss %g" % (i, j, xloss))
            
    if i % 2 == 0:
        acc = sess.run(accuracy, feed_dict={x:valid_corpus_embed, y:valid_label})
        print("epoch %d, Validation acc: %g" % (i, acc * 100), end="")
        print("%")

# %% [markdown]
# ## Questions

# %% [markdown]
# - What are the benefits and downsides of the RNN-based representation over the bag of words representation used last week?
# - How would availability of data affect your answer?
# - One possible architectural variant is to use only the final hidden state of the RNN as the document representation (i.e., x) rather than the average of the hidden states over time. How does this work? What are the potential benefits and downsides to this representation?
# - Try different RNN architectures, e.g., simple Elman RNNs or GRUs or LSTMs. Which ones work best?
# - What happens if you use a bidirectional LSTM (i.e., the dashed arrows in the figure)?
