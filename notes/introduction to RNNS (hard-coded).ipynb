# %% [markdown]
# ## Setup

# %%
from __future__ import print_function, division
import numpy as np 
import tensorflow as tf 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
num_epochs = 100 
total_series_length = 50000
truncated_backprop_length = 15 
state_size = 4 
num_classes = 2 
echo_step = 3
batch_size = 5 
num_batches = total_series_length//batch_size//truncated_backprop_length

# %% [markdown]
# ## Generate data

# %%
def generateData():
    x = np.array(np.random.choice(2, total_series_length, p=[0.5, 0.5]))
    y = np.roll(x, echo_step)
    y[0:echo_step] = 0

    x = x.reshape((batch_size, -1))  # The first index changing slowest, subseries as rows
    y = y.reshape((batch_size, -1))

    return (x, y)

# %% [markdown]
# ## Build the computational graph

# %%
batchX_placeholder = tf.placeholder(tf.float32, [batch_size, truncated_backprop_length])
batchY_placeholder = tf.placeholder(tf.int32, [batch_size, truncated_backprop_length])

init_state = tf.placeholder(tf.float32, [batch_size, state_size])

# %%
W = tf.Variable(np.random.rand(state_size+1, state_size), dtype=tf.float32)
b = tf.Variable(np.zeros((1,state_size)), dtype=tf.float32)

W2 = tf.Variable(np.random.rand(state_size, num_classes),dtype=tf.float32)
b2 = tf.Variable(np.zeros((1,num_classes)), dtype=tf.float32)

# %%
# Unpack columns
inputs_series = tf.unstack(batchX_placeholder, axis=1)
labels_series = tf.unstack(batchY_placeholder, axis=1)

# %%
print(len(inputs_series))
print(inputs_series[0].shape)
# Out:
# 15
# (5,)

# %% [markdown]
# ## Forward pass

# %%
current_state = init_state
states_series = []
for current_input in inputs_series:
    current_input = tf.reshape(current_input, [batch_size, 1])
    input_and_state_concatenated = tf.concat([current_input, current_state], 1)
    
    next_state = tf.tanh(tf.matmul(input_and_state_concatenated, W) + b)
    states_series.append(next_state)
    current_state = next_state

# %%
print(current_state.shape)
# Out:
# (5, 4)

# %% [markdown]
# ## Calculating loss

# %%
logits_series = [tf.matmul(state, W2) + b2 for state in states_series] #Broadcasted addition
print(logits_series[0].shape)
predictions_series = [tf.nn.softmax(logits) for logits in logits_series]
print(predictions_series[0].shape)

losses = [tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=labels) for logits, labels in zip(logits_series,labels_series)]
total_loss = tf.reduce_mean(losses)

train_step = tf.train.AdagradOptimizer(0.3).minimize(total_loss)
# Out:
# (5, 2)
# (5, 2)

# %% [markdown]
# ## Visualize the training

# %%
def plot(loss_list, predictions_series, batchX, batchY):
    plt.subplot(2, 3, 1)
    plt.cla()
    plt.plot(loss_list)

    for batch_series_idx in range(5):
        one_hot_output_series = np.array(predictions_series)[:, batch_series_idx, :]
        single_output_series = np.array([(1 if out[0] < 0.5 else 0) for out in one_hot_output_series])

        plt.subplot(2, 3, batch_series_idx + 2)
        plt.cla()
        plt.axis([0, truncated_backprop_length, 0, 2])
        left_offset = range(truncated_backprop_length)
        plt.bar(left_offset, batchX[batch_series_idx, :], width=1, color="blue")
        plt.bar(left_offset, batchY[batch_series_idx, :] * 0.5, width=1, color="red")
        plt.bar(left_offset, single_output_series * 0.3, width=1, color="green")

    plt.draw()
    plt.pause(0.0001)

# %% [markdown]
# ## Run a training session

# %%
with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    plt.ion()
    plt.figure()
    plt.show()
    loss_list = []

    for epoch_idx in range(num_epochs):
        x,y = generateData()
        _current_state = np.zeros((batch_size, state_size))

        print("New data, epoch", epoch_idx)

        for batch_idx in range(num_batches):
            start_idx = batch_idx * truncated_backprop_length
            end_idx = start_idx + truncated_backprop_length

            batchX = x[:,start_idx:end_idx]
            batchY = y[:,start_idx:end_idx]

            _total_loss, _train_step, _current_state, _predictions_series = sess.run(
                [total_loss, train_step, current_state, predictions_series],
                feed_dict={
                    batchX_placeholder:batchX,
                    batchY_placeholder:batchY,
                    init_state:_current_state
                })

            loss_list.append(_total_loss)

            if batch_idx%100 == 0:
                print("Step",batch_idx, "Loss", _total_loss)
                plot(loss_list, _predictions_series, batchX, batchY)

plt.ioff()
plt.show()
# Out:
# WARNING:tensorflow:From <ipython-input-27-081f153bf0a5>:2: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# New data, epoch 0
# Step 0 Loss 0.704709
# Step 100 Loss 0.692816
# Step 200 Loss 0.693926
# Step 300 Loss 0.687964
# Step 400 Loss 0.706352
# Step 500 Loss 0.68548
# Step 600 Loss 0.702873
# New data, epoch 1
# Step 0 Loss 0.692181
# Step 100 Loss 0.691288
# Step 200 Loss 0.52849
# Step 300 Loss 0.297915
# Step 400 Loss 0.0263566
# Step 500 Loss 0.0124024
# Step 600 Loss 0.00655138
# New data, epoch 2
# Step 0 Loss 0.202678
# Step 100 Loss 0.00437201
# Step 200 Loss 0.00378472
# Step 300 Loss 0.00281191
# Step 400 Loss 0.00308754
# Step 500 Loss 0.0026168
# Step 600 Loss 0.00203264
# New data, epoch 3
# Step 0 Loss 0.143777
# Step 100 Loss 0.00174731
# Step 200 Loss 0.00210237
# Step 300 Loss 0.00131076
# Step 400 Loss 0.00130733
# Step 500 Loss 0.00126269
# Step 600 Loss 0.00110277
# New data, epoch 4
# Step 0 Loss 0.188036
# Step 100 Loss 0.00154579
# Step 200 Loss 0.00106535
# Step 300 Loss 0.000872981
# Step 400 Loss 0.00103128
# Step 500 Loss 0.000875904
# Step 600 Loss 0.00079361
# New data, epoch 5
# Step 0 Loss 0.256829
# Step 100 Loss 0.000844122
# Step 200 Loss 0.000724915
# Step 300 Loss 0.000742516
# Step 400 Loss 0.000719757
# Step 500 Loss 0.000785907
# Step 600 Loss 0.000682885
# New data, epoch 6
# Step 0 Loss 0.191561
# Step 100 Loss 0.00345717
# Step 200 Loss 0.00223649
# Step 300 Loss 0.00202789
# Step 400 Loss 0.00160507
# Step 500 Loss 0.00158696
# Step 600 Loss 0.00120976
# New data, epoch 7
# Step 0 Loss 0.190514
# Step 100 Loss 0.00111932
# Step 200 Loss 0.000908405
# Step 300 Loss 0.00093027
# Step 400 Loss 0.00094754
# Step 500 Loss 0.000849462
# Step 600 Loss 0.000845934
# New data, epoch 8
# Step 0 Loss 0.227573
# Step 100 Loss 0.000711618
# Step 200 Loss 0.000709781
# Step 300 Loss 0.000901195
# Step 400 Loss 0.000680115
# Step 500 Loss 0.000628391
# Step 600 Loss 0.000557557
# New data, epoch 9
# Step 0 Loss 0.194505
# Step 100 Loss 0.000610443
# Step 200 Loss 0.000544903
# Step 300 Loss 0.000555613
# Step 400 Loss 0.000458264
# Step 500 Loss 0.000412256
# Step 600 Loss 0.000543966
# New data, epoch 10
# Step 0 Loss 0.17745
# Step 100 Loss 0.000495606
# Step 200 Loss 0.000456665
# Step 300 Loss 0.000453158
# Step 400 Loss 0.000398326
# Step 500 Loss 0.000473468
# Step 600 Loss 0.000521415
# New data, epoch 11
# Step 0 Loss 0.206676
# Step 100 Loss 0.000329016
# Step 200 Loss 0.000426571
# Step 300 Loss 0.000409033
# Step 400 Loss 0.000371192
# Step 500 Loss 0.000362779
# Step 600 Loss 0.000328483
# New data, epoch 12
# Step 0 Loss 0.125245
# Step 100 Loss 0.000339344
# Step 200 Loss 0.000287096
# Step 300 Loss 0.000382803
# Step 400 Loss 0.000305048
# Step 500 Loss 0.000316547
# Step 600 Loss 0.000294259
# New data, epoch 13
# Step 0 Loss 0.176848
# Step 100 Loss 0.000398261
# Step 200 Loss 0.000302051
# Step 300 Loss 0.00033067
# Step 400 Loss 0.000295722
# Step 500 Loss 0.000274415
# Step 600 Loss 0.000290603
# New data, epoch 14
# Step 0 Loss 0.163241
# Step 100 Loss 0.000356509
# Step 200 Loss 0.000304707
# Step 300 Loss 0.000290266
# Step 400 Loss 0.000265336
# Step 500 Loss 0.000258801
# Step 600 Loss 0.000255613
# New data, epoch 15
# Step 0 Loss 0.155944
# Step 100 Loss 0.000272017
# Step 200 Loss 0.000265693
# Step 300 Loss 0.000229999
# Step 400 Loss 0.000259438
# Step 500 Loss 0.000214445
# Step 600 Loss 0.000242217
# New data, epoch 16
# Step 0 Loss 0.161407
# Step 100 Loss 0.000227139
# Step 200 Loss 0.000236699
# Step 300 Loss 0.00024125
# Step 400 Loss 0.000231162
# Step 500 Loss 0.000202529
# Step 600 Loss 0.00021005
# New data, epoch 17
# Step 0 Loss 0.17999
# Step 100 Loss 0.000205849
# Step 200 Loss 0.000219326
# Step 300 Loss 0.000174918
# Step 400 Loss 0.000202768
# Step 500 Loss 0.000203857
# Step 600 Loss 0.000181608
# New data, epoch 18
# Step 0 Loss 0.109886
# Step 100 Loss 0.000187505
# Step 200 Loss 0.000198375
# Step 300 Loss 0.00018221
# Step 400 Loss 0.000188339
# Step 500 Loss 0.000194886
# Step 600 Loss 0.000187308
# New data, epoch 19
# Step 0 Loss 0.185614
# Step 100 Loss 0.000195475
# Step 200 Loss 0.000194918
# Step 300 Loss 0.000185774
# Step 400 Loss 0.000196546
# Step 500 Loss 0.000194708
# Step 600 Loss 0.000195151
# New data, epoch 20
# Step 0 Loss 0.147815
# Step 100 Loss 0.000191858
# Step 200 Loss 0.000192882
# Step 300 Loss 0.000184903
# Step 400 Loss 0.000185312
# Step 500 Loss 0.000228641
# Step 600 Loss 0.0001995
# New data, epoch 21
# Step 0 Loss 0.144432
# Step 100 Loss 0.000148659
# Step 200 Loss 0.000149553
# Step 300 Loss 0.000223275
# Step 400 Loss 0.000145372
# Step 500 Loss 0.000156935
# Step 600 Loss 0.000174963
# New data, epoch 22
# Step 0 Loss 0.18875
# Step 100 Loss 0.000326406
# Step 200 Loss 0.00018118
# Step 300 Loss 0.000180624
# Step 400 Loss 0.000144191
# Step 500 Loss 0.000171456
# Step 600 Loss 0.000198472
# New data, epoch 23
# Step 0 Loss 0.202403
# Step 100 Loss 0.000246072
# Step 200 Loss 0.000227967
# Step 300 Loss 0.000180908
# Step 400 Loss 0.000180385
# Step 500 Loss 0.000160137
# Step 600 Loss 0.00015132
# New data, epoch 24
# Step 0 Loss 0.160102
# Step 100 Loss 0.000165721
# Step 200 Loss 0.000203615
# Step 300 Loss 0.000136044
# Step 400 Loss 0.000162531
# Step 500 Loss 0.000155757
# Step 600 Loss 0.000113191
# New data, epoch 25
# Step 0 Loss 0.262758
# Step 100 Loss 0.000217025
# Step 200 Loss 0.000179968
# Step 300 Loss 0.000217355
# Step 400 Loss 0.000162272
# Step 500 Loss 0.000137185
# Step 600 Loss 0.000140209
# New data, epoch 26
# Step 0 Loss 0.186546
# Step 100 Loss 0.000162382
# Step 200 Loss 0.000199194
# Step 300 Loss 0.000147527
# Step 400 Loss 0.000126801
# Step 500 Loss 0.00012858
# Step 600 Loss 0.000141307
# New data, epoch 27
# Step 0 Loss 0.172806
# Step 100 Loss 0.000145063
# Step 200 Loss 0.000129604
# Step 300 Loss 0.000123273
# Step 400 Loss 0.000112578
# Step 500 Loss 0.000112988
# Step 600 Loss 0.000125014
# New data, epoch 28
# Step 0 Loss 0.170342
# Step 100 Loss 0.000231011
# Step 200 Loss 0.000182169
# Step 300 Loss 0.00013427
# Step 400 Loss 0.000134574
# Step 500 Loss 0.000127205
# Step 600 Loss 0.000139681
# New data, epoch 29
# Step 0 Loss 0.161201
# Step 100 Loss 0.000156595
# Step 200 Loss 0.000127394
# Step 300 Loss 0.00014429
# Step 400 Loss 0.00012672
# Step 500 Loss 0.000119192
# Step 600 Loss 0.000151866
# New data, epoch 30
# Step 0 Loss 0.152299
# Step 100 Loss 0.000206587
# Step 200 Loss 0.000192934
# Step 300 Loss 0.000164952
# Step 400 Loss 0.00013753
# Step 500 Loss 0.000110272
# Step 600 Loss 0.000130584
# New data, epoch 31
# Step 0 Loss 0.192209
# Step 100 Loss 0.000129805
# Step 200 Loss 0.000110001
# Step 300 Loss 0.000102666
# Step 400 Loss 0.000103367
# Step 500 Loss 0.00012108
# Step 600 Loss 0.000114564
# New data, epoch 32
# Step 0 Loss 0.129446
# Step 100 Loss 0.000109736
# Step 200 Loss 0.000117195
# Step 300 Loss 0.000115375
# Step 400 Loss 9.98791e-05
# Step 500 Loss 0.000104275
# Step 600 Loss 9.85377e-05
# New data, epoch 33
# Step 0 Loss 0.213425
# Step 100 Loss 0.000128642
# Step 200 Loss 0.000117391
# Step 300 Loss 0.000130244
# Step 400 Loss 0.00011353
# Step 500 Loss 0.000107784
# Step 600 Loss 0.000120159
# New data, epoch 34
# Step 0 Loss 0.165652
# Step 100 Loss 0.00013918
# Step 200 Loss 9.61036e-05
# Step 300 Loss 0.000121079
# Step 400 Loss 0.000127276
# Step 500 Loss 9.87321e-05
# Step 600 Loss 0.000111877
# New data, epoch 35
# Step 0 Loss 0.162918
# Step 100 Loss 8.17551e-05
# Step 200 Loss 9.4396e-05
# Step 300 Loss 0.000111529
# Step 400 Loss 9.84006e-05
# Step 500 Loss 9.92282e-05
# Step 600 Loss 0.000100931
# New data, epoch 36
# Step 0 Loss 0.138332
# Step 100 Loss 0.000117884
# Step 200 Loss 0.000100412
# Step 300 Loss 9.70235e-05
# Step 400 Loss 0.000102934
# Step 500 Loss 0.000102519
# Step 600 Loss 8.66102e-05
# New data, epoch 37
# Step 0 Loss 0.156751
# Step 100 Loss 9.33951e-05
# Step 200 Loss 9.14925e-05
# Step 300 Loss 8.35366e-05
# Step 400 Loss 9.53005e-05
# Step 500 Loss 0.00010002
# Step 600 Loss 7.89212e-05
# New data, epoch 38
# Step 0 Loss 0.133448
# Step 100 Loss 9.16041e-05
# Step 200 Loss 8.77147e-05
# Step 300 Loss 8.25443e-05
# Step 400 Loss 0.000101087
# Step 500 Loss 7.69395e-05
# Step 600 Loss 8.71389e-05
# New data, epoch 39
# Step 0 Loss 0.140621
# Step 100 Loss 7.58047e-05
# Step 200 Loss 9.94278e-05
# Step 300 Loss 9.12632e-05
# Step 400 Loss 9.45326e-05
# Step 500 Loss 9.48569e-05
# Step 600 Loss 9.1714e-05
# New data, epoch 40
# Step 0 Loss 0.160933
# Step 100 Loss 9.2968e-05
# Step 200 Loss 8.81344e-05
# Step 300 Loss 8.51067e-05
# Step 400 Loss 7.6795e-05
# Step 500 Loss 0.000126748
# Step 600 Loss 8.2062e-05
# New data, epoch 41
# Step 0 Loss 0.178403
# Step 100 Loss 0.000111851
# Step 200 Loss 9.20018e-05
# Step 300 Loss 0.000172555
# Step 400 Loss 0.000110728
# Step 500 Loss 0.000140599
# Step 600 Loss 9.22988e-05
# New data, epoch 42
# Step 0 Loss 0.171913
# Step 100 Loss 9.57623e-05
# Step 200 Loss 6.025e-05
# Step 300 Loss 7.4047e-05
# Step 400 Loss 8.0516e-05
# Step 500 Loss 7.96029e-05
# Step 600 Loss 8.07071e-05
# New data, epoch 43
# Step 0 Loss 0.148678
# Step 100 Loss 0.000102575
# Step 200 Loss 9.01948e-05
# Step 300 Loss 9.30906e-05
# Step 400 Loss 8.29705e-05
# Step 500 Loss 7.84612e-05
# Step 600 Loss 8.34042e-05
# New data, epoch 44
# Step 0 Loss 0.160384
# Step 100 Loss 0.000146513
# Step 200 Loss 0.000116548
# Step 300 Loss 9.12162e-05
# Step 400 Loss 7.72728e-05
# Step 500 Loss 7.99051e-05
# Step 600 Loss 8.37392e-05
# New data, epoch 45
# Step 0 Loss 0.164371
# Step 100 Loss 9.92646e-05
# Step 200 Loss 8.24466e-05
# Step 300 Loss 8.61701e-05
# Step 400 Loss 0.000121432
# Step 500 Loss 7.75842e-05
# Step 600 Loss 9.71164e-05
# New data, epoch 46
# Step 0 Loss 0.156552
# Step 100 Loss 8.21715e-05
# Step 200 Loss 8.00655e-05
# Step 300 Loss 7.95486e-05
# Step 400 Loss 7.18572e-05
# Step 500 Loss 7.25158e-05
# Step 600 Loss 8.16387e-05
# New data, epoch 47
# Step 0 Loss 0.16952
# Step 100 Loss 8.323e-05
# Step 200 Loss 6.93246e-05
# Step 300 Loss 6.49116e-05
# Step 400 Loss 7.30343e-05
# Step 500 Loss 9.34129e-05
# Step 600 Loss 8.21993e-05
# New data, epoch 48
# Step 0 Loss 0.119907
# Step 100 Loss 6.60162e-05
# Step 200 Loss 6.73609e-05
# Step 300 Loss 6.97366e-05
# Step 400 Loss 6.28631e-05
# Step 500 Loss 6.48052e-05
# Step 600 Loss 6.28408e-05
# New data, epoch 49
# Step 0 Loss 0.149733
# Step 100 Loss 8.1545e-05
# Step 200 Loss 8.95069e-05
# Step 300 Loss 8.60233e-05
# Step 400 Loss 7.48934e-05
# Step 500 Loss 9.48771e-05
# Step 600 Loss 9.33715e-05
# New data, epoch 50
# Step 0 Loss 0.22742
# Step 100 Loss 6.23214e-05
# Step 200 Loss 9.05359e-05
# Step 300 Loss 6.86277e-05
# Step 400 Loss 6.68711e-05
# Step 500 Loss 6.44017e-05
# Step 600 Loss 6.21084e-05
# New data, epoch 51
# Step 0 Loss 0.140251
# Step 100 Loss 7.22836e-05
# Step 200 Loss 5.49642e-05
# Step 300 Loss 8.30404e-05
# Step 400 Loss 6.06174e-05
# Step 500 Loss 7.32647e-05
# Step 600 Loss 7.19772e-05
# New data, epoch 52
# Step 0 Loss 0.113231
# Step 100 Loss 6.80406e-05
# Step 200 Loss 6.82019e-05
# Step 300 Loss 6.17602e-05
# Step 400 Loss 6.98557e-05
# Step 500 Loss 7.78038e-05
# Step 600 Loss 5.95018e-05
# New data, epoch 53
# Step 0 Loss 0.138523
# Step 100 Loss 7.2111e-05
# Step 200 Loss 7.52422e-05
# Step 300 Loss 7.15018e-05
# Step 400 Loss 8.98572e-05
# Step 500 Loss 6.043e-05
# Step 600 Loss 6.238e-05
# New data, epoch 54
# Step 0 Loss 0.165252
# Step 100 Loss 5.80822e-05
# Step 200 Loss 7.1922e-05
# Step 300 Loss 6.65911e-05
# Step 400 Loss 5.89565e-05
# Step 500 Loss 6.12834e-05
# Step 600 Loss 5.44416e-05
# New data, epoch 55
# Step 0 Loss 0.144655
# Step 100 Loss 5.03489e-05
# Step 200 Loss 5.7895e-05
# Step 300 Loss 6.43859e-05
# Step 400 Loss 7.07152e-05
# Step 500 Loss 6.42936e-05
# Step 600 Loss 4.93079e-05
# New data, epoch 56
# Step 0 Loss 0.159142
# Step 100 Loss 5.5015e-05
# Step 200 Loss 6.31936e-05
# Step 300 Loss 6.8654e-05
# Step 400 Loss 5.86418e-05
# Step 500 Loss 5.25423e-05
# Step 600 Loss 5.51295e-05
# New data, epoch 57
# Step 0 Loss 0.148476
# Step 100 Loss 5.77135e-05
# Step 200 Loss 7.86892e-05
# Step 300 Loss 6.06984e-05
# Step 400 Loss 5.8394e-05
# Step 500 Loss 5.6895e-05
# Step 600 Loss 5.75661e-05
# New data, epoch 58
# Step 0 Loss 0.230029
# Step 100 Loss 5.96791e-05
# Step 200 Loss 7.67375e-05
# Step 300 Loss 7.87736e-05
# Step 400 Loss 8.13359e-05
# Step 500 Loss 8.63808e-05
# Step 600 Loss 7.04359e-05
# New data, epoch 59
# Step 0 Loss 0.131151
# Step 100 Loss 6.06179e-05
# Step 200 Loss 6.57727e-05
# Step 300 Loss 6.63539e-05
# Step 400 Loss 6.31869e-05
# Step 500 Loss 5.8783e-05
# Step 600 Loss 6.3168e-05
# New data, epoch 60
# Step 0 Loss 0.131
# Step 100 Loss 5.87388e-05
# Step 200 Loss 7.09205e-05
# Step 300 Loss 5.9975e-05
# Step 400 Loss 4.745e-05
# Step 500 Loss 5.22559e-05
# Step 600 Loss 6.00065e-05
# New data, epoch 61
# Step 0 Loss 0.188385
# Step 100 Loss 5.84037e-05
# Step 200 Loss 5.61069e-05
# Step 300 Loss 6.11133e-05
# Step 400 Loss 4.91251e-05
# Step 500 Loss 6.48611e-05
# Step 600 Loss 5.22626e-05
# New data, epoch 62
# Step 0 Loss 0.179451
# Step 100 Loss 5.79233e-05
# Step 200 Loss 6.04424e-05
# Step 300 Loss 5.32683e-05
# Step 400 Loss 5.08654e-05
# Step 500 Loss 5.58236e-05
# Step 600 Loss 5.45144e-05
# New data, epoch 63
# Step 0 Loss 0.142239
# Step 100 Loss 6.6095e-05
# Step 200 Loss 5.85577e-05
# Step 300 Loss 5.3545e-05
# Step 400 Loss 5.54949e-05
# Step 500 Loss 5.84714e-05
# Step 600 Loss 5.64785e-05
# New data, epoch 64
# Step 0 Loss 0.180335
# Step 100 Loss 8.4333e-05
# Step 200 Loss 7.25525e-05
# Step 300 Loss 8.48072e-05
# Step 400 Loss 5.88402e-05
# Step 500 Loss 6.30041e-05
# Step 600 Loss 5.18298e-05
# New data, epoch 65
# Step 0 Loss 0.0686117
# Step 100 Loss 5.22553e-05
# Step 200 Loss 7.49453e-05
# Step 300 Loss 5.68067e-05
# Step 400 Loss 5.48284e-05
# Step 500 Loss 5.6791e-05
# Step 600 Loss 6.62473e-05
# New data, epoch 66
# Step 0 Loss 0.287051
# Step 100 Loss 5.37625e-05
# Step 200 Loss 5.01501e-05
# Step 300 Loss 5.97114e-05
# Step 400 Loss 5.07986e-05
# Step 500 Loss 5.86148e-05
# Step 600 Loss 4.58319e-05
# New data, epoch 67
# Step 0 Loss 0.159221
# Step 100 Loss 5.14671e-05
# Step 200 Loss 5.62479e-05
# Step 300 Loss 6.24017e-05
# Step 400 Loss 6.96077e-05
# Step 500 Loss 6.39697e-05
# Step 600 Loss 5.09234e-05
# New data, epoch 68
# Step 0 Loss 0.17428
# Step 100 Loss 5.59698e-05
# Step 200 Loss 5.94343e-05
# Step 300 Loss 5.19093e-05
# Step 400 Loss 5.57921e-05
# Step 500 Loss 5.17952e-05
# Step 600 Loss 4.7693e-05
# New data, epoch 69
# Step 0 Loss 0.147448
# Step 100 Loss 6.14677e-05
# Step 200 Loss 5.01229e-05
# Step 300 Loss 5.37197e-05
# Step 400 Loss 5.09332e-05
# Step 500 Loss 4.89868e-05
# Step 600 Loss 5.00406e-05
# New data, epoch 70
# Step 0 Loss 0.180351
# Step 100 Loss 5.42554e-05
# Step 200 Loss 5.62961e-05
# Step 300 Loss 5.69888e-05
# Step 400 Loss 4.94399e-05
# Step 500 Loss 6.29951e-05
# Step 600 Loss 6.11328e-05
# New data, epoch 71
# Step 0 Loss 0.167103
# Step 100 Loss 0.000138366
# Step 200 Loss 7.52325e-05
# Step 300 Loss 7.73533e-05
# Step 400 Loss 5.51102e-05
# Step 500 Loss 6.74615e-05
# Step 600 Loss 6.76346e-05
# New data, epoch 72
# Step 0 Loss 0.159125
# Step 100 Loss 5.07139e-05
# Step 200 Loss 6.8037e-05
# Step 300 Loss 5.21965e-05
# Step 400 Loss 5.44047e-05
# Step 500 Loss 5.58e-05
# Step 600 Loss 6.69832e-05
# New data, epoch 73
# Step 0 Loss 0.164517
# Step 100 Loss 5.22972e-05
# Step 200 Loss 4.9214e-05
# Step 300 Loss 6.19451e-05
# Step 400 Loss 6.91044e-05
# Step 500 Loss 4.99736e-05
# Step 600 Loss 4.84385e-05
# New data, epoch 74
# Step 0 Loss 0.229422
# Step 100 Loss 4.64153e-05
# Step 200 Loss 5.52752e-05
# Step 300 Loss 4.81205e-05
# Step 400 Loss 4.41662e-05
# Step 500 Loss 6.04974e-05
# Step 600 Loss 5.39183e-05
# New data, epoch 75
# Step 0 Loss 0.119246
# Step 100 Loss 5.31774e-05
# Step 200 Loss 5.21314e-05
# Step 300 Loss 5.27896e-05
# Step 400 Loss 6.14541e-05
# Step 500 Loss 5.55916e-05
# Step 600 Loss 6.03017e-05
# New data, epoch 76
# Step 0 Loss 0.236283
# Step 100 Loss 5.23505e-05
# Step 200 Loss 5.17568e-05
# Step 300 Loss 5.1461e-05
# Step 400 Loss 5.59265e-05
# Step 500 Loss 5.17156e-05
# Step 600 Loss 4.17362e-05
# New data, epoch 77
# Step 0 Loss 0.120847
# Step 100 Loss 5.85529e-05
# Step 200 Loss 5.16903e-05
# Step 300 Loss 5.44981e-05
# Step 400 Loss 5.30396e-05
# Step 500 Loss 4.26771e-05
# Step 600 Loss 4.7906e-05
# New data, epoch 78
# Step 0 Loss 0.196136
# Step 100 Loss 5.76602e-05
# Step 200 Loss 5.26253e-05
# Step 300 Loss 6.00267e-05
# Step 400 Loss 5.60048e-05
# Step 500 Loss 6.13551e-05
# Step 600 Loss 5.86568e-05
# New data, epoch 79
# Step 0 Loss 0.256219
# Step 100 Loss 4.8758e-05
# Step 200 Loss 5.10164e-05
# Step 300 Loss 4.53632e-05
# Step 400 Loss 4.42839e-05
# Step 500 Loss 4.30982e-05
# Step 600 Loss 4.24419e-05
# New data, epoch 80
# Step 0 Loss 0.165284
# Step 100 Loss 7.09765e-05
# Step 200 Loss 4.58565e-05
# Step 300 Loss 4.03296e-05
# Step 400 Loss 4.74115e-05
# Step 500 Loss 5.67436e-05
# Step 600 Loss 5.34669e-05
# New data, epoch 81
# Step 0 Loss 0.198838
# Step 100 Loss 3.85272e-05
# Step 200 Loss 3.94396e-05
# Step 300 Loss 4.63103e-05
# Step 400 Loss 4.59589e-05
# Step 500 Loss 4.74117e-05
# Step 600 Loss 3.71494e-05
# New data, epoch 82
# Step 0 Loss 0.140545
# Step 100 Loss 4.5333e-05
# Step 200 Loss 5.00946e-05
# Step 300 Loss 4.70334e-05
# Step 400 Loss 4.92093e-05
# Step 500 Loss 4.47974e-05
# Step 600 Loss 3.5641e-05
# New data, epoch 83
# Step 0 Loss 0.138515
# Step 100 Loss 4.18776e-05
# Step 200 Loss 3.99578e-05
# Step 300 Loss 4.20811e-05
# Step 400 Loss 3.77342e-05
# Step 500 Loss 3.9333e-05
# Step 600 Loss 4.52852e-05
# New data, epoch 84
# Step 0 Loss 0.12825
# Step 100 Loss 5.60883e-05
# Step 200 Loss 5.07079e-05
# Step 300 Loss 4.56315e-05
# Step 400 Loss 4.74005e-05
# Step 500 Loss 5.26605e-05
# Step 600 Loss 5.19999e-05
# New data, epoch 85
# Step 0 Loss 0.176157
# Step 100 Loss 4.70029e-05
# Step 200 Loss 4.19695e-05
# Step 300 Loss 5.30582e-05
# Step 400 Loss 4.34127e-05
# Step 500 Loss 4.13834e-05
# Step 600 Loss 5.77417e-05
# New data, epoch 86
# Step 0 Loss 0.177482
# Step 100 Loss 3.68854e-05
# Step 200 Loss 3.99482e-05
# Step 300 Loss 4.00165e-05
# Step 400 Loss 3.99544e-05
# Step 500 Loss 4.56332e-05
# Step 600 Loss 4.04981e-05
# New data, epoch 87
# Step 0 Loss 0.156132
# Step 100 Loss 4.62827e-05
# Step 200 Loss 4.00609e-05
# Step 300 Loss 5.79507e-05
# Step 400 Loss 5.90991e-05
# Step 500 Loss 4.68043e-05
# Step 600 Loss 4.27534e-05
# New data, epoch 88
# Step 0 Loss 0.208305
# Step 100 Loss 4.28709e-05
# Step 200 Loss 3.53836e-05
# Step 300 Loss 3.67186e-05
# Step 400 Loss 3.96097e-05
# Step 500 Loss 4.31413e-05
# Step 600 Loss 3.70222e-05
# New data, epoch 89
# Step 0 Loss 0.134587
# Step 100 Loss 3.99449e-05
# Step 200 Loss 4.18536e-05
# Step 300 Loss 4.5274e-05
# Step 400 Loss 4.61181e-05
# Step 500 Loss 4.19746e-05
# Step 600 Loss 3.83555e-05
# New data, epoch 90
# Step 0 Loss 0.159534
# Step 100 Loss 3.91899e-05
# Step 200 Loss 3.90692e-05
# Step 300 Loss 4.3912e-05
# Step 400 Loss 4.56937e-05
# Step 500 Loss 4.12293e-05
# Step 600 Loss 4.16805e-05
# New data, epoch 91
# Step 0 Loss 0.169652
# Step 100 Loss 4.92463e-05
# Step 200 Loss 4.64357e-05
# Step 300 Loss 4.28915e-05
# Step 400 Loss 4.05583e-05
# Step 500 Loss 3.26514e-05
# Step 600 Loss 3.70572e-05
# New data, epoch 92
# Step 0 Loss 0.172198
# Step 100 Loss 4.70214e-05
# Step 200 Loss 5.09859e-05
# Step 300 Loss 4.20524e-05
# Step 400 Loss 4.4643e-05
# Step 500 Loss 4.46748e-05
# Step 600 Loss 5.04896e-05
# New data, epoch 93
# Step 0 Loss 0.174474
# Step 100 Loss 8.95266e-05
# Step 200 Loss 5.58065e-05
# Step 300 Loss 4.8802e-05
# Step 400 Loss 5.33158e-05
# Step 500 Loss 4.92653e-05
# Step 600 Loss 4.76065e-05
# New data, epoch 94
# Step 0 Loss 0.16789
# Step 100 Loss 4.64037e-05
# Step 200 Loss 3.8171e-05
# Step 300 Loss 3.41898e-05
# Step 400 Loss 3.92058e-05
# Step 500 Loss 4.72494e-05
# Step 600 Loss 4.98145e-05
# New data, epoch 95
# Step 0 Loss 0.148536
# Step 100 Loss 4.2341e-05
# Step 200 Loss 3.77294e-05
# Step 300 Loss 3.6744e-05
# Step 400 Loss 4.1024e-05
# Step 500 Loss 4.24847e-05
# Step 600 Loss 3.64958e-05
# New data, epoch 96
# Step 0 Loss 0.222628
# Step 100 Loss 4.90387e-05
# Step 200 Loss 3.80091e-05
# Step 300 Loss 3.76594e-05
# Step 400 Loss 3.94364e-05
# Step 500 Loss 4.02468e-05
# Step 600 Loss 3.69347e-05
# New data, epoch 97
# Step 0 Loss 0.123518
# Step 100 Loss 4.17805e-05
# Step 200 Loss 3.05057e-05
# Step 300 Loss 3.40166e-05
# Step 400 Loss 4.43569e-05
# Step 500 Loss 3.905e-05
# Step 600 Loss 3.86036e-05
# New data, epoch 98
# Step 0 Loss 0.204039
# Step 100 Loss 4.43028e-05
# Step 200 Loss 3.60972e-05
# Step 300 Loss 3.70968e-05
# Step 400 Loss 4.07698e-05
# Step 500 Loss 4.10443e-05
# Step 600 Loss 3.69756e-05
# New data, epoch 99
# Step 0 Loss 0.191153
# Step 100 Loss 5.15649e-05
# Step 200 Loss 4.50404e-05
# Step 300 Loss 4.27261e-05
# Step 400 Loss 3.65486e-05
# Step 500 Loss 3.39133e-05
# Step 600 Loss 4.45651e-05
